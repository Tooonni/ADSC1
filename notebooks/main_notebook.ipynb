# %% [markdown]
# # Imports

# %%
import os
import glob
from pathlib import Path
from bs4 import BeautifulSoup
import pandas as pd
import sqlite3
import requests
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.pipeline import make_pipeline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Create Database

# %%
#Hier wird das Pattern für Zeitschriften festgelegt

PATTERN_FOR_FAZ = "**/*faz*.html"
PATTERN_FOR_SZ = "**/*sz*.html"
PATTERN_FOR_WELT = "**/*welt*.html"

# %%
all_path_to_faz = glob.glob(os.path.join(Path.cwd().parent / "input", PATTERN_FOR_FAZ))
all_path_to_sz = glob.glob(os.path.join(Path.cwd().parent / "input", PATTERN_FOR_SZ))
all_path_to_welt = glob.glob(os.path.join(Path.cwd().parent / "input", PATTERN_FOR_WELT))
all_path = all_path_to_faz + all_path_to_sz + all_path_to_welt

# %%
print(len(all_path_to_faz))
print(len(all_path_to_sz))
print(len(all_path_to_welt))
print(len(all_path))
# Out:
# 92
# 92
# 92
# 276

# %% [markdown]
# ## HTML Analysis for FAZ

# %%
all_path_to_faz[0]
# Out:
# '/Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/input/data-lake_2024_11/2024-11-23-faz.html'

# %%
with open(all_path_to_faz[0], "r") as f:
    html = f.read()

# %%
bs = BeautifulSoup(html, "html.parser")

# %%
teasers = bs.select(".teaser-object__title, .top1-teaser__body-title")

for teaser in teasers:
    # Titel extrahieren
    title = teaser.get_text(strip=True)

    # Zum nächsten Geschwisterelement gehen, um den passenden Text zu finden
    text_element = teaser.find_next(class_="teaser-object__teaser-text")
    text = text_element.get_text(strip=True) if text_element else " "

    print("Titel:", title)
    print("Text:", text)
    print("-" * 50)
print(len(teasers))
# Out:
# Titel: Der richtige Mann in der falschen Partei?
# Text: Boris Pistorius verzichtet auf die Kandidatur und unterstützt Olaf Scholz. Doch der steht als gescheiterer Kanzler da. Und bis zum SPD-Parteitag im Januar kann noch viel passieren.
# --------------------------------------------------
# Titel: Das Ende einer bizarren K-Frage
# Text: Pistorius hätte die Debatte im Keim ersticken können. Er ließ sie laufen. Gerade noch rechtzeitig zog er jetzt die Notbremse. Der Schaden für Scholz und die SPD ist dennoch groß.
# --------------------------------------------------
# Titel: Was das Northvolt-Debakel für Europa bedeutet
# Text: Der schwedische Batterie-Pionier Northvolt kämpft ums Überleben. Kann Europa den Vorsprung der Konkurrenz aus Asien überhaupt noch wettmachen?
# --------------------------------------------------
# Titel: Das zähe Klimaringen in Baku nimmt kein Ende
# Text: Auch die Verlängerung ins Wochenende hinein hat bisher keinen Durchbruch auf der Weltklimakonferenz gebracht. Sowohl Entwicklungs- als auch Industriestaaten fühlen sich übervorteilt.
# --------------------------------------------------
# Titel: „Wir kommen nicht so schnell voran, wie es möglich wäre“
# Text: Kommenden Montag findet in Berlin ein Long-Covid-Kongress statt. Die Charité-Immunologin Carmen Scheibenbogen hofft, dass Therapien Betroffenen bald ursächlich helfen – beklagt im Interview jedoch hohe Hürden für die Forschung.
# --------------------------------------------------
# Titel: Mit vereinten Kräften gegen den Tod
# Text: Die Slalomläuferin Lucrezia Lorenzi hat kürzlich ihre Schwester nach einem Skiunfall verloren. Jetzt kämpft die Italienerin für mehr Sicherheit auf den Weltcup-Pisten.
# --------------------------------------------------
# Titel: Der größte Cyberangriff in den USA
# Text: Chinesische Hacker haben die Telekommunikation der USA infiltriert, aufhalten kann sie offenbar niemand. Denn dazu müsste man „Abertausende von Geräten im ganzen Land“ austauschen.
# --------------------------------------------------
# Titel: Aufgemischter Bankenmarkt und Tipps von einem Hundertjährigen
# Text: Mit unserem Angebot FAZ+ erhalten Sie jeden Monat Zugriff auf mehr als 1000 exklusive Beiträge auf FAZ.NET. Unter anderem auf diese beliebtesten Stücke der Woche.
# --------------------------------------------------
# Titel: Warum Wagenknecht auf einmal eingelenkt hat
# Text: Mit Machttechniken wie aus einer Kaderpartei wollte Sahra Wagenknecht die Koalition in Thüringen verhindern. Und dann, auf einmal, zeigte sie sich wie verwandelt.
# --------------------------------------------------
# Titel: Merkels Schelte für Scholz
# Text: Zum Verkaufsstart ihrer Memoiren gibt Angela Merkel ihre Zurückhaltung auf, die aktuelle Politik zu kommentieren. So macht man Schlagzeilen – und neugierig auf das Buch.
# --------------------------------------------------
# Titel: Der Staat muss dringend effizienter werden
# Text: Die Privatwirtschaft wächst nicht, wohl aber der Staat. Das ist kein Rezept für einen Wirtschaftsaufschwung.
# --------------------------------------------------
# Titel: Für die Menschen
# Text: Die Reform ist ein Erfolg für Lauterbach. Eine Überarbeitung ist möglich, aber das Ziel sollte bleiben: nicht hohle Besitzstandswahrung, sondern ein besseres Gesundheitssystem.
# --------------------------------------------------
# Titel: Jungs mit 26
# Text: Ein Berliner Professor überrascht mit dem Vorschlag, jungen Männern erst mit 26 Jahren den Führerschein zu geben. Das ist weltfremd, führt aber zu schönen Gedankenexperimenten.
# --------------------------------------------------
# Titel: Wut der Städte ist unglaubwürdig
# Text: Veranstalter von Weihnachtsmärkten beklagen die gestiegenen GEMA-Gebühren. Das Problem ist hausgemacht: Die Städte haben sich nicht an ihre Vereinbarungen mit der GEMA gehalten.
# --------------------------------------------------
# Titel: Das Ende einer bizarren K-Frage
# Text: Pistorius hätte die Debatte im Keim ersticken können. Er ließ sie laufen. Gerade noch rechtzeitig zog er jetzt die Notbremse. Der Schaden für Scholz und die SPD ist dennoch groß.
# --------------------------------------------------
# Titel: Rückenwind für Siemens
# Text: Siemens Energy hat sich stabilisiert und genießt wieder Vertrauen an der Börse. Das eröffnet dem Großaktionär Siemens AG neuen Spielraum.
# --------------------------------------------------
# Titel: NATO-Generalsekretär trifft Trump in Florida
# Text: Gespräch über „globale Sicherheitsprobleme" +++ Strafmaßverkündung gegen Trump auf unbestimmte Zeit verschoben +++ Chef der US-Börsenaufsicht tritt mit Trumps Vereidigung ab +++ Alle Neuigkeiten im Liveblog
# --------------------------------------------------
# Titel: Vorbild Elon Musk: Alle zurück ins Büro?
# Text: Trump macht Musk zum Leiter für Regierungseffizienz. Sein Plan: Homeoffice wird gestrichen. Wir sprechen mit F.A.Z.-Korrespondent Winand von Petersdorff, F.A.Z.-Herausgeber Carsten Knop und Homeoffice-Forscher Florian Kunze.
# --------------------------------------------------
# Titel: Vorbild Elon Musk: Alle zurück ins Büro?
# Text: Trump macht Musk zum Leiter für Regierungseffizienz. Sein Plan: Homeoffice wird gestrichen. Wir sprechen mit F.A.Z.-Korrespondent Winand von Petersdorff, F.A.Z.-Herausgeber Carsten Knop und Homeoffice-Forscher Florian Kunze.
# --------------------------------------------------
# Titel: Trump nominiert prominenten Investor Scott Bessent als Finanzminister
# Text: Hedgefonds-Manager Scott Bessent soll der nächste US-Finanzminister werden. In dieser Funktion müsste Bessent Trumps Agenda von niedrigen Steuern, Deregulierung und hohen Zöllen durchsetzen.
# --------------------------------------------------
# Titel: Trump nominiert prominenten Investor Scott Bessent als Finanzminister
# Text: Hedgefonds-Manager Scott Bessent soll der nächste US-Finanzminister werden. In dieser Funktion müsste Bessent Trumps Agenda von niedrigen Steuern, Deregulierung und hohen Zöllen durchsetzen.
# --------------------------------------------------
# Titel: Putin will Mittelstreckenraketen in Serie produzieren
# Text: Der Kreml brüstet sich mit seiner neuen Mittelstreckenrate. Der ukrainische Präsident Selenskyj hingegen spricht von Kriegsverbrechen und fordert scharfe Reaktionen. Die EU-Parlamentspräsidentin verlangt von Berlin Taurus-Waffenhilfe für Kiew. Der Überblick.
# --------------------------------------------------
# Titel: Nan Goldin sorgt für Eklat
# Text: Bei der Eröffnung ihrer Ausstellung hält die Künstlerin Nan Goldin eine Rede, in der sie Israels Vorgehen in Gaza kritisiert. Im Anschluss wird der Direktor der Nationalgalerie von pro-palästinensischen  Demonstranten niedergebrüllt.
# --------------------------------------------------
# Titel: In Deutschland wächst nur der Staat
# Text: Die Wirtschaft hat zwischen Juli und September noch weniger zugelegt als gedacht. Nur Gesundheit und Erziehung legen zu. Verdüstern sich die Aussichten weiter?
# --------------------------------------------------
# Titel: Rechtsextreme Siedler bedrängen israelischen General im Westjordanland
# Text: Dutzende beschimpfen Avi Bluth in Hebron als „Verräter“ +++ Heftiger Luftangriff auf Beirut +++ Israelischer Botschafter Prosor: Haftbefehl gegen Netanjahu „absurd“ +++ Biden und Macron diskutieren Waffenruhe für Libanon  +++ alle Entwicklungen im Liveblog
# --------------------------------------------------
# Titel: Und ewig heilen die Berge
# Text: Kommen Sie, atmen Sie! Wie innere Leuchtkraft die Nebensaison im Engadin beleben soll.
# --------------------------------------------------
# Titel: Eine Kugel Weiß, bitte
# Text: Reinraum des Minimalismus statt Bußarchitektur der Nachkriegszeit: Die Hedwigskathedrale in Berlin ist jetzt mehr Pantheon als Kirche.
# --------------------------------------------------
# Titel: Wir Geisterfahrer
# Text: GastbeitragDie jetzige Krise der deutschen Industrie ist noch schlimmer als die Misere, die Schröder einst mit seiner Agenda 2010 bewältigte. Deutschland steht an einem historischen Wendepunkt. Seine Existenz als globale Wirtschaftsnation ist in Gefahr.
# --------------------------------------------------
# Titel: Wie die Immobilie zum Schonvermögen wird
# Text: Nichts ist in den Menschen so tief verwurzelt wie die Angst vor der Inflation und der Wunsch nach den eigenen vier Wänden. Doch ohne ausreichende Vorsorge droht im Pflegefall der Verlust des Hauses.
# --------------------------------------------------
# Titel: Wie die Immobilie zum Schonvermögen wird
# Text: Nichts ist in den Menschen so tief verwurzelt wie die Angst vor der Inflation und der Wunsch nach den eigenen vier Wänden. Doch ohne ausreichende Vorsorge droht im Pflegefall der Verlust des Hauses.
# --------------------------------------------------
# Titel: Wo finden Erfolgsfrauen Männer ohne Egoprobleme?
# Text: Viele ambitionierte Singlefrauen treffen immer wieder auf Männer, die weib­liches Selbstbewusstsein so sehr einschüchtert, dass eine Beziehung keine Chance hat. Eine neue Dating-App will helfen, dieses Problem zu lösen.
# --------------------------------------------------
# Titel: Wo finden Erfolgsfrauen Männer ohne Egoprobleme?
# Text: Viele ambitionierte Singlefrauen treffen immer wieder auf Männer, die weib­liches Selbstbewusstsein so sehr einschüchtert, dass eine Beziehung keine Chance hat. Eine neue Dating-App will helfen, dieses Problem zu lösen.
# --------------------------------------------------
# Titel: Bundeswehr bereitet Unternehmen auf den Kriegsfall vor
# Text: In einem geheimen Strategiepapier ist die Rolle der Wirtschaft klar umrissen, sollte Putin im Osten angreifen. Die Bundeswehr hat konkrete Vorschläge, wie Unternehmen sich wappnen sollten.
# --------------------------------------------------
# Titel: Donnerstag 23 Uhr, ab ins Fitnessstudio
# Text: Das Training im Studio ist in vielen Städten zur Jugendbewegung geworden – oft zur Verblüffung der Eltern. Doch hinter dem Drang steckt mehr als nur das Ziel, Bizeps und Sixpack zu stärken.
# --------------------------------------------------
# Titel: Ein Haus mit zwei Erben
# Text: Zwei Brüder erben gemeinsam ihr Elternhaus. Leider spielt das Finanzamt nicht so mit, wie sie sich das dachten.
# --------------------------------------------------
# Titel: Wann ist die finanzielle Unabhängigkeit erreicht?
# Text: Aufhören zu arbeiten und nur noch vom Vermögen leben: Davon träumen manche. Hier kommt eine Übersicht, was dafür nötig ist.
# --------------------------------------------------
# Titel: Putin droht westlichen Waffengebern mit Angriff
# Text: Der Trump-Beauftragte, Tesla-Chef und Milliardär will Behördenmitarbeitern das mobile Arbeiten verbieten. Kann das deutschen Beschäftigten auch passieren?
# --------------------------------------------------
# Titel: Elon Musks Frontalangriff auf das Homeoffice
# Text: Der Trump-Beauftragte, Tesla-Chef und Milliardär will Behördenmitarbeitern das mobile Arbeiten verbieten. Kann das deutschen Beschäftigten auch passieren?
# --------------------------------------------------
# Titel: Die Deutschen spüren die schlechte Wirtschaftslage nicht
# Text: Eine Mehrheit der Bevölkerung sieht Deutschland auf dem wirtschaftlichen Abstieg. Ihre eigene Lage schätzen die Menschen aber gut ein. Was heißt das für die Wahl?
# --------------------------------------------------
# Titel: Ein langes juristisches Nachspiel
# Text: Vor mehr als fünf Jahren kamen die Ermittlungen zur AWO-Affäre ins Rollen, in die auch der damalige Oberbürgermeister Frankfurts verstrickt war. Sie beschäftigt bis heute die Frankfurter Gerichte. Mehrere Verfahren sind noch nicht abgeschlossen.
# --------------------------------------------------
# Titel: Bemühungen um Waffenruhe in Libanon gehen nur schleppend voran
# Text: Frankreich und die USA wollen einen Waffenstillstand vermitteln – doch noch geht der Krieg zwischen Israel und der Hizbullah ungebremst weiter. Im Ostlibanon wurden ein Krankenhausdirektor und sechs seiner Mitarbeiter getötet. Der Überblick.
# --------------------------------------------------
# Titel: Würde Deutschland Benjamin Netanjahu festnehmen?
# Text: Das Völkerrecht ist klar: Die Bundesregierung muss Haftbefehle des Internationalen Gerichtshofs vollstrecken. Berlin will aber an Israels Seite stehen. Und jetzt?
# --------------------------------------------------
# Titel: Trump will Rechtmäßigkeit der Wahl 2020 untersuchen lassen
# Text: Die „Washington Post“ berichtet, dass in den umkämpften Bundesstaaten nach Beweisen dafür gesucht werden sollen, dass Donald Trump die Wahl 2020 in Wahrheit gewonnen hatte und nur durch Betrug zum Verlierer wurde.
# --------------------------------------------------
# Titel: Deutschland hat 8263 freiwillige Ausreisen finanziell gefördert
# Text: Wenn Migranten doch keine Zukunft in Deutschland sehen, können sie als Hilfe für die Rückreise Geld beantragen. Bis Oktober 2024 haben Tausende Menschen das Angebot in Anspruch genommen. Laut Befürwortern lohnt sich die Praxis.
# --------------------------------------------------
# Titel: „Die Ampelregierung war immer schwach“
# Text: Der Milliardär Klaus-Michael Kühne hat viel Geld mit der Benko-Pleite verloren. Im Interview spricht er zudem über die Fehler der Lufthansa, wie er seinen Nachlass regelt und über die Nazivergangenheit seiner Familie.
# --------------------------------------------------
# Titel: „Sanktionen sind notwendig, aber kein Allheilmittel“
# Text: Die CDU will das Bürgergeld abschaffen, die Ampelparteien sind sich einig: Das Bürgergeld bietet einen guten Rahmen, es braucht jedoch einige Anpassungen. Nur welche?
# --------------------------------------------------
# Titel: Wird der Bahn der Geldhahn abgedreht?
# Text: Kindergeld, Bürgergeld, Wärmepumpenförderung: Diese Leistungen laufen auch ohne einen verabschiedeten Haushalt weiter. Aber das gilt nicht für alles.
# --------------------------------------------------
# Titel: Ein US-Investor will Nord Stream 2 kaufen
# Text: Die umstrittene Pipeline könnte nächstes Jahr versteigert werden. Dann will Stephen Lynch zuschlagen, der Kontakte zur russischen Regierung hat. Was verspricht er sich davon?
# --------------------------------------------------
# Titel: KI ist Männersache – und warum das nicht gut ist
# Text: Künstliche Intelligenz wird nicht nur von Männern deutlich häufiger genutzt als von Frauen. Männer sind auch an der Erstellung der KI-Modelle viel intensiver beteiligt, haben besseren Zugang zur KI in ihren Unternehmen und zu KI-Jobs.
# --------------------------------------------------
# Titel: Das ChatGPT für Juristen – nur besser
# Text: Das Berliner Start-up Xayn will mit KI die Recherchezeit für juristische Sachverhalte drastisch verkürzen. Komplette Subsumtionen sollen künftig in Minuten statt Stunden möglich sein.
# --------------------------------------------------
# Titel: Die besten Tricks für die neue Suchmaschine von Open AI
# Text: SearchGPT von Open AI erzeugt aus aktuellen Webinhalten Antworten – auch zum Tagesgeschehen. Aber nur wer richtig fragt, bekommt auch brauchbare Ergebnisse. Diese Tricks können den Zeitaufwand deutlich verringern.
# --------------------------------------------------
# Titel: Dieser Dax-Wert ist besser als Nvidia
# Text: Die Börsenstars kommen längst nicht nur aus dem Silicon Valley. Auch ein Black-Friday-Schnäppchen hält der Dax bereit.
# --------------------------------------------------
# Titel: So funktioniert das ETF-Wunderportfolio
# Text: Das Depot besteht aus einem Anleihe- und einem Aktien-ETF und verspricht Anlegern, die Profis an der Börse schlagen zu können. Nun bekommt es frischen Rückenwind. So funktioniert es.
# --------------------------------------------------
# Titel: Wie man verhindert, für die Pflege der Eltern zahlen zu müssen
# Text: Reicht das Vermögen der Eltern nicht mehr, werden häufig die Kinder zur Kasse gebeten. Doch es gibt Möglichkeiten, um das abzuwenden. Entscheidend ist die Vorbereitung.
# --------------------------------------------------
# Titel: Ran an die 7,7 Billionen Euro
# Text: Die Klimawende müsse von Privaten finanziert werden, findet das Beratungsgremium der Ampel zu nachhaltigen Finanzen. Nur wie?
# --------------------------------------------------
# Titel: Die Geschichte meiner Exzesse
# Text: Die Nan-Goldin-Ausstellung in Berlin wird von antiisraelischen Statements der Künstlerin überschattet. Jenseits aller Debatten kann man in der Neuen Nationalgalerie ihr fotografisches Lebenswerk entdecken.
# --------------------------------------------------
# Titel: Nach dem Abitur gab es Rehrücken auf dem Hummerfelsen
# Text: Seit über vierzig Jahren kursiert ein Text, den Franz Kafka über seine Helgoland-Reise von 1901 verfasst haben soll. Doch hat den Text überhaupt Kafka geschrieben – oder wer ist der wahre Autor? Eine Spurensuche.
# --------------------------------------------------
# Titel: Der ermäßigte Steuersatz kommt
# Text: 7 statt 19 Prozent: Die Senkung des Mehrwertsteuersatzes für Kunst ist beschlossene Sache. Im Bundesrat nimmt das Jahressteuergesetz seine letzte Hürde. Der deutsche Kunsthandel kann aufatmen.
# --------------------------------------------------
# Titel: English National Opera zieht um
# Text: Nach den Nötigungen des britischen Kulturrates bereitet die English National Opera ihren Umzug von London nach Manchester vor. Die Zukunftspläne setzten auf Jugend, Experiment, Teilhabe und Vielfalt. Nur herkömmliche Oper ist kaum noch zu finden.
# --------------------------------------------------
# Titel: Der Campus ist kein Schutzraum mehr
# Text: Wie stark wirkt sich der politische Rechtsruck auf das Klima an deutschen Universitäten aus? Unsere Autorin meint: Man spürt die wachsende Spannung schon im Seminarraum.
# --------------------------------------------------
# Titel: Bye-bye, Kantinenfraß
# Text: Regional, mit vegetarischen Optionen, teils auf Restaurantniveau: Die Qualität der Kantinen nimmt zu. Das lockt sogar Mitarbeiter aus dem Homeoffice ins Büro.
# --------------------------------------------------
# Titel: Schicksal einer Bauruine
# Text: Die Reform der akademischen Karrierewege tritt nach dem Ampel-Aus auf der Stelle. Welche Ziele verfolgt das Ministerium überhaupt?
# --------------------------------------------------
# Titel: Kane, Kane, Kane
# Text: Zuerst passiert nicht viel zwischen Bayern und Augsburg. Doch dann trifft Harry Kane gleich dreimal.
# --------------------------------------------------
# Titel: „Wir haben jetzt gerade einen Ossi gehabt, das reicht“
# Text: HSV-Trainer Steffen Baumgart verrät im Interview, wie hoch die Ansprüche in Hamburg sind, was er von Fußball-Experten hält und was Vorbehalte ihm gegenüber mit seiner ostdeutschen Herkunft zu tun haben.
# --------------------------------------------------
# Titel: Davis-Cup-Team verpasst Finale
# Text: Deutschlands Tennis-Profis haben den Sprung ins Davis-Cup-Finale verpasst. Das Erfolgsdoppel kommt gar nicht erst zum Einsatz.
# --------------------------------------------------
# Titel: Plötzlich am Ziel seiner Träume
# Text: Dass er mal für sein Heimatland Schweden auflaufen würde, hätte Isac Lidberg noch vor Kurzem für unmöglich gehalten. Jetzt aber ist er in der Form seines Lebens. Davon soll auch Darmstadt 98 profitieren.
# --------------------------------------------------
# Titel: Täter machen Millionenbeute bei Überfall auf Museum für religiöse Kunst
# Text: Noch rund zwanzig Besucher sind im Museum, als vier Diebe im Hieron-Museum  Schüsse abgaben. Dann sägten sie Panzerglas durch.
# --------------------------------------------------
# Titel: Krönung von König Charles verursacht Kosten von rund 86 Millionen Euro
# Text: Die Zeremonie für König Charles war unter anderem wegen der vermuteten Kosten kritisiert worden. Nun wurde bekannt, wie hoch diese tatsächlich waren.
# --------------------------------------------------
# Titel: Abou-Chakers wegen falscher Durchfall-Atteste verurteilt
# Text: Zwei Abou-Chaker-Brüder wollten mit falschen Durchfall-Attesten ein Berliner Gericht täuschen. Der Beschiss flog auf.
# --------------------------------------------------
# Titel: Findet der in Australien gestrandete Kaiserpinguin zurück in die Antarktis?
# Text: Die Strandung eines Kaiserpinguins in Australien sorgte für Aufsehen. Nun ist Gus wieder im Ozean. Wie stehen die Chancen, dass er zurück in die Antarktis findet?
# --------------------------------------------------
# Titel: Ein Genie ist selten allein
# Text: Wes Andersons Filme sehen manchmal selbst wie Museen aus. Welche Inspirationen liegen dem Design zugrunde? Ein neues Buch geht dem auf den Grund.
# --------------------------------------------------
# Titel: Die Besten in Küche und Keller
# Text: Jedes Jahr ziehen unsere Genusskolumnisten Jürgen Dollase und Stephan Reinhardt Bilanz: Wer sind die herausragenden Köche und Winzer? Deren Spitzenleistungen zu genießen, dazu ist bei unserer Gala Gelegenheit.
# --------------------------------------------------
# Titel: Abschotten, Aufrüsten, Soldaten für Putin: Nordkoreas neuer Masterplan
# Text: Nordkorea und Russland rücken zusammen, eine Entwicklung die den neuen US-Präsidenten Trump vor Herausforderungen stellen wird. Wir erklären die Zusammenhänge.
# --------------------------------------------------
# Titel: Abschotten, Aufrüsten, Soldaten für Putin: Nordkoreas neuer Masterplan
# Text: Nordkorea und Russland rücken zusammen, eine Entwicklung die den neuen US-Präsidenten Trump vor Herausforderungen stellen wird. Wir erklären die Zusammenhänge.
# --------------------------------------------------
# Titel: Von Demis Hassabis lernen: Wie KI die Wissenschaft umpflügt
# Text: DNA, Proteine, Fusionsenergie und mehr – die Künstliche Intelligenz hat für Forscher ein gewaltiges und gefährliches Potential. Darum geht es.
# --------------------------------------------------
# Titel: Erfolg im Kampf gegen die Schweinepest
# Text: Die äußerste Sperrzone im Kampf gegen die Afrikanische Schweinepest wird in Südhessen Ende November teilweise aufgehoben. Landwirtschaftsminister Jung bezeichnet das als „wichtigen Erfolgen“. Entwarnung ist aber noch nicht angesagt.
# --------------------------------------------------
# Titel: Grüne durch weiteres Beweisstück belastet
# Text: Ihr Ko-Vorsitzender Andreas Ewald sei auf seinen Auslandsreisen als Privatmann unterwegs gewesen, versicherten die hessischen Grünen der Bundestagsverwaltung. Dass dies eine falsche Auskunft war, wird jetzt besonders anschaulich belegt.
# --------------------------------------------------
# Titel: Ermittlungen gegen fast hundert Fans
# Text: Ein Jahr nach den Ausschreitungen beim Spiel der Frankfurter Eintracht gegen den VfB Stuttgart stellt die Staatsanwaltschaft eine vorläufige Bilanz der Ermittlungen vor. Doch eine Frage bleibt offen.
# --------------------------------------------------
# Titel: „Diese Tage sind ein Auf und Ab der Gefühle“
# Text: Mit dem Eröffnungskonzert ist es wieder so weit: Sechs Nominierte treten in Kronberg zum Wettbewerb um den Internationalen Deutschen Pianistenpreis an. Im Livestream können Sie mithören.
# --------------------------------------------------
# Titel: Die Feinschmecker-Edition Pralinen mit Geschenkbeutel
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Vollmachten für den Fall der Fälle - eBook Verfügungen, Vollmachten, Vorlagen
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Auto-Shopping mit PS leicht gemacht: Mehr als 1,4 Millionen Fahrzeuge
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Master-Studiengang: Medien- und Kommunikationsmanagement
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Verbessern Sie Ihr Englisch
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Verkaufen Sie zum Höchstpreis
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Spanischkurs für Anfänger
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Geld einfacher anlegen mit dem Finanzrechner
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Neugier auf Zukunft
# Text: Flotte Akkus, stromerzeugende Lacke und wartungsfreie Bremsen: Das Auto der Zukunft ist weit mehr als ein Smartphone auf Rädern. Ein Besuch im Forschungslabor von Mercedes-Benz.
# --------------------------------------------------
# Titel: Der Bursche fürs Grobe
# Text: Der Dacia Duster ist auch in der Neuauflage eine Klasse für sich und ein beliebtes Vehikel, das muss einen Grund haben. Wir fanden noch einen zweiten links unten am Armaturenbrett.
# --------------------------------------------------
# Titel: Management: Jobs finden
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Vertrieb & Verkauf: Jobs finden
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Alle Studiengänge im Überblick
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Jetzt bei Dr. Maier + Partner bewerben
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Jura: Jobs finden
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Vorstand und Geschäftsführung: Jobs finden
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Englisch im Beruf
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Jobs für Fach- und Führungskräfte: Jetzt bei Kienbaum bewerben
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Der mysteriöse Mollusk
# Text: Im Pazifik wurde ein bizarres Tier entdeckt. Es ist ein Verwandter der Seeschnecken, aber ein so weitläufiger, dass er als bisher einziger Vertreter einer eigenen, neuen Tierfamilie eingestuft wurde.
# --------------------------------------------------
# Titel: Das Adipositas-Paradox
# Text: Besonders junge Frauen scheinen trotz Übergewichts vor Erkrankungen wie Diabetes Typ 2 geschützt. Das könnte jedoch nur ein Zwischenstadium sein.
# --------------------------------------------------
# Titel: Was passiert, wenn Wunscheltern ihre Gene testen lassen?
# Text: Tausenden Paaren mit Kinderwunsch wurden in einer Studie Gentests angeboten. Viele nahmen das Angebot an, einige änderten ihre Familienpläne. Was sagen Ethiker dazu?
# --------------------------------------------------
# Titel: Das F.A.Z.-Magazin zum Download
# Text: In Baku bewegen sich Industrie- und Entwicklungsländer langsam aufeinander zu. Allerdings ist für eine Einigung noch viel zu tun.
# --------------------------------------------------
# Titel: Das Newsquiz zu den Nachrichten des Tages
# Text: In Baku bewegen sich Industrie- und Entwicklungsländer langsam aufeinander zu. Allerdings ist für eine Einigung noch viel zu tun.
# --------------------------------------------------
# Titel: Immer im Bilde
# Text: In Baku bewegen sich Industrie- und Entwicklungsländer langsam aufeinander zu. Allerdings ist für eine Einigung noch viel zu tun.
# --------------------------------------------------
# Titel: Das F.A.Z.-Magazin auf Instagram
# Text: In Baku bewegen sich Industrie- und Entwicklungsländer langsam aufeinander zu. Allerdings ist für eine Einigung noch viel zu tun.
# --------------------------------------------------
# Titel: Klimakonferenz geht in die Verlängerung
# Text: In Baku bewegen sich Industrie- und Entwicklungsländer langsam aufeinander zu. Allerdings ist für eine Einigung noch viel zu tun.
# --------------------------------------------------
# Titel: „Die Welt muss in Baku in den Notfallmodus schalten“
# Text: Niklas Höhne, Klimaforscher und Gründer des New-Climate-Institutes, fordert von der Bundesregierung eine Billion Euro, um die Erderwärmung aufzuhalten. Er setzt Hoffnungen in die Photovoltaik – und in China.
# --------------------------------------------------
# Titel: Kein Klimaschutz ohne China
# Text: Ohne den größten CO₂-Emittenten muss globaler Klimaschutz scheitern. Was hat China auf den kohlenstoffintensiven Weg gebracht? Und wie ernst meint es Peking mit der Energiewende?
# --------------------------------------------------
# Titel: Sucht die Weisheit, nicht den Tod!
# Text: Gelehrte und Gewaltherrscher, Astronomen und Autokraten prägen diese Weltgegend bis heute: Eine berauschend gemächliche Fahrt mit dem Orient Silk Road Express durch vier Länder Zentralasiens.
# --------------------------------------------------
# Titel: Verbessern Sie Ihr Englisch auf Reisen
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Für Ihre nächste Reise nach Frankreich
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Autos für Ihre nächste Reise
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Lernen Sie für Ihre nächste Reise einfach online Italienisch
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Lernen Sie Spanisch für die Reise einfach online
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Der beste Koffer
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Große Weine aus Kalifornien inklusive Booklet
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Die ganze Reise festhalten - nicht nur Fotos davon
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Der Riesling der Nationalspieler
# Text: Jetzt machen auch Mats Hummels, Christoph Kramer und Robin Gosens in Wein. Mit zwei Pfälzer Winzern haben sie eine durchaus anspruchsvolle Riesling-Cuvée „kreiert“.
# --------------------------------------------------
# Titel: Die Sache mit dem Adventskalender
# Text: Damit Liebgewordenes nicht langweilig wird: Ein Vater und eine Mutter erzählen, was sie diesmal für ihre Kinder vorbereitet und welchen Rat sie für Adventskalender-Anfänger haben.
# --------------------------------------------------
# Titel: „Wir sehen eine verzögerte Autonomieentwicklung“
# Text: Werden Jugendliche erwachsen, brechen sie häufig ihre Psychotherapie ab. Das ist problematisch, sagt Psychiater Gerd Schulte-Körner. Er erklärt, wie man das verhindern kann.
# --------------------------------------------------
# Titel: Mein Haus auf deinem Grund
# Text: Wer in der Stadt Häuser bauen oder kaufen will, kommt am ­Erbbaurecht oft nicht mehr vorbei. Aus guten Gründen. Doch ein Schnäppchen ist das selten.
# --------------------------------------------------
# Titel: Proviant für den nächsten Ausflug in die Blockchain
# Text: Der Krypto-Tycoon Justin Sun ersteigert in New York Bananenkunst zu 6,2 Millionen Dollar, und ein Bild Magrittes wird teuerstes Kunstwerk des Jahres. Für einen neuen Höhenrausch in den Auktionssälen sorgt das aber noch nicht.
# --------------------------------------------------
# Titel: Eines Freundes guter Traum und das eigene böse Wachsein
# Text: Erstmals seit 2018 gelangt eine literarische Handschrift Franz Kafkas in den Handel: „Erstes Leid“ von 1922 wird bei Hesse in Hamburg zusammen mit einem Brief des Schriftstellers versteigert.
# --------------------------------------------------
# Titel: Die eigentliche Heldin heißt Rose Valland
# Text: Ohne sie hätten die Monuments Men wenig gefunden: Im Zweiten Weltkrieg spionierte Rose Valland aus, wohin die Nazis ihre Raubkunst verschleppten. Nun wird ein berühmtes Werk, das sie zu retten half, in Paris versteigert.
# --------------------------------------------------
# Titel: Mietpreisbremse soll ausgeweitet werden
# Text: Das Linksbündnis in Wiesbaden will die Mietpreisbremse auch für die frei finanzierten Wohnungen der städtischen Gesellschaften. Die Stadtverordneten sollen nun darüber abstimmen.
# --------------------------------------------------
# Titel: „Wir könnten mehr Pragmatik vertragen“
# Text: Eigentlich kann es auch im Bau ganz schnell gehen – man muss als Stadt nur wollen, sagt Jan Linsin von CBRE im Gespräch. Die Politik kann aber trotzdem Hürden abbauen.
# --------------------------------------------------
# Titel: Wie ein Ehepaar sein Haus zur Energieoase gemacht hat
# Text: Das Frankfurter Ehepaar Köhler hat in ein nachhaltiges Eigenheim investiert. Mit innovativen Energielösungen und staatlicher Förderung setzt es nicht nur auf Klimaschutz, sondern vor allem auch auf wirtschaftliche Unabhängigkeit.
# --------------------------------------------------
# Titel: Verkaufen Sie zum Höchstpreis
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Das Investment meines Lebens
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Finden Sie Ihren neuen Nachhauseweg
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Die besten Hausnotrufe im Vergleich
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Immobilien zum Kauf in Hamburg
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Kredite für Möbel und Einrichtungen: Jetzt vergleichen
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Exklusive Wegbegleiter und Wohnaccessoires
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Finden Sie Ihren neuen Nachhauseweg
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Du gehörst mir, also töte ich dich
# Text: Die F.A.Z. hat erstmals untersucht, wie Gerichte in Deutschland mit Tötungsdelikten an Frauen umgehen. Die Recherche zeigt: Manche Gerichte werten das Besitzdenken des Täters nicht als besonders verwerflich – und ein Teil erkennt es erst gar nicht.
# --------------------------------------------------
# Titel: Das sind die besten Beauty-Neuheiten 2024
# Text: Auch in diesem Jahr sind unzählige neue Beauty-Produkte erschienen. Unsere Autorin behält den Überblick: Sie hat die wichtigsten Neuheiten getestet.
# --------------------------------------------------
# Titel: Verkohlte Zeugen des Krieges
# Text: Zwischen Minen und Blindgängern löschen ukrainische Waldarbeiter lodernde Feuer. Der Fotograf Thomas Peter hat sie während ihres gefährlichen Jobs begleitet.
# --------------------------------------------------
# 137

# %% [markdown]
# ## HTML Analysis for SZ

# %%
all_path_to_sz[0]
# Out:
# '/Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/input/data-lake_2024_11/2024-11-05-sz.html'

# %%
with open(all_path_to_sz[0], "r") as f:
    html = f.read()

# %%
bs = BeautifulSoup(html, "html.parser")

# %%
articles = bs.find_all("article")

for article in articles:
    # Titel suchen
    title_element = article.select_one('[data-manual="teaser-title"]')
    title = title_element.get_text(strip=True) if title_element else " "

    # Text suchen
    text_element = article.select_one('[data-manual="teaser-text"]')
    text = text_element.get_text(strip=True) if text_element else " "

    print("Titel:", title)
    print("Text:", text)
    print("-" * 50)
print(len(articles))
# Out:
# Titel: Wehe, wenn Trump verliert
# Text: Sollte Kamala Harris die US-Präsidentschaftswahl für sich entscheiden, dürfte ihr Kontrahent Himmel und Hölle in Bewegung setzen, um doch noch Präsident zu werden. Wie er das Ergebnis zu seinen Gunsten drehen könnte.
# --------------------------------------------------
# Titel: Das sagen die Umfragen - ein Überblick in Grafiken
# Text:
# --------------------------------------------------
# Titel: Auf diesen Sendern können Sie die US-Wahl live verfolgen
# Text:
# --------------------------------------------------
# Titel: Harris feiert Abschlusskundgebung mit US-Promis
# Text: Die Demokratin setzt am letzten Wahlkampftag auf Superstars und gute Stimmung, ihr Konkurrent hetzt gegen Einwanderer und fantasiert über Käfigkämpfe. In einem Dorf im Norden ist die Wahl bereits gelaufen.
# --------------------------------------------------
# Titel: „Ich werde Donald Trump wählen, auch wenn ich ihn nicht leiden kann“
# Text: Devon wählt republikanisch, Chloe demokratisch und Ellis libertär. Was sie eint, ist die Sorge um ihre Zukunft. Hier erzählen drei junge Amerikaner, wie sie die Wahl erleben.
# --------------------------------------------------
# Titel: Wäre ein Trump-Sieg doch das kleinere Übel?
# Text: Louis Klamroths Gäste befinden sich im Talkshow-Endspurt vor der US-Wahl. Der Tenor: Ein Trump-Sieg könnte Gefahren für die Demokratie bringen – eine Niederlage des Ex-Präsidenten aber auch.
# --------------------------------------------------
# Titel: Zulieferer Schaeffler baut Tausende Stellen ab - auch in Deutschland
# Text:
# --------------------------------------------------
# Titel: Nato-Chef Rutte fordert höhere Rüstungsausgaben von Berlin
# Text:
# --------------------------------------------------
# Titel: Streik bei Boeing zu Ende – Mitarbeiter nehmen Angebot an
# Text:
# --------------------------------------------------
# Titel: US-Regierung dringt auf mehr humanitäre Hilfe für Gazastreifen
# Text:
# --------------------------------------------------
# Titel: Südkorea: Nordkorea feuert mehrere ballistische Raketen ab
# Text:
# --------------------------------------------------
# Titel: Der Körper als Waffe
# Text: Eine Studentin in Iran zieht sich wohl aus Protest gegen das Regime aus – und das halbe Internet erklärt sich solidarisch. Doch zwischen Empathie und Herablassung liegt manchmal nur ein schmaler Grat.
# --------------------------------------------------
# Titel: Die Emanzipation vom Über-Klopp
# Text: Nach neun Jahren Jürgen Klopp war die Frage, wie der FC Liverpool bloß ohne diesen Trainer weitermachen soll. Antwort: ziemlich gut. Unter dem Niederländer Arne Slot blüht auf, was der Deutsche einst gesät hat - klappt es auch gegen Alonsos Leverkusen?
# --------------------------------------------------
# Titel: Xabi Alonso wird zum Pragmatiker
# Text:
# --------------------------------------------------
# Titel: Was Estland zum Bildungschampion macht
# Text: Nirgends in Europa sind die Pisa-Ergebnisse so gut wie in dem baltischen Land, wo die Kinder neun Jahre zusammen lernen. Warum läuft es dort besser als anderswo?
# --------------------------------------------------
# Titel: Wie viel Druck braucht Schule?
# Text:
# --------------------------------------------------
# Titel: „Das ist wieder so eine richtige Idiotentätigkeit“
# Text: Schon wieder wurde der wohl berühmteste Kreisverkehr Deutschlands beschädigt: Im März fällten Unbekannte den Baum des „Franz-Eberhofer-Kreisels“, jetzt wurde der neue Baum demoliert. Was ist da los?
# --------------------------------------------------
# Titel: Noch ein Bierchen auf den Verbrenner
# Text: Seit Jahrzehnten gibt es die „Tunnel Schänke“ in Wolfsburg, gleich am Werkstor 17 von VW. Viel ist zwar nicht mehr los, aber den Puls der Autobranche kann man hier immer noch ertasten. Gespräche zwischen Tresen und Topfpflanze.
# --------------------------------------------------
# Titel: Stürzen Sie im Traum auch manchmal in die Tiefe?
# Text: Albträume wie den Falltraum sollte man nicht ignorieren, sagt Experte Michael Schredl. Hier erklärt er, was wir aus unseren Albträumen über uns lernen können – und wie man ihnen verblüffend einfach ein Happy End verpasst.
# --------------------------------------------------
# Titel: „Man muss diese ersten Sekunden, Minuten, Stunden überhaupt überleben können“
# Text: Der Tod ihres Sohnes vor 26 Jahren war für Freya von Stülpnagel der absolute Super-GAU, wie sie sagt. Deshalb hat sie ein Projekt gegründet, das Familien durch die Trauer begleitet. Wie hält man das aus, wenn man selbst Betroffene ist?
# --------------------------------------------------
# Titel: Lindners „Wirtschaftswende“ schadet der Wirtschaft
# Text:
# --------------------------------------------------
# Titel: Falls Trump gewählt wird, muss die Ampel unbedingt durchhalten
# Text:
# --------------------------------------------------
# Titel: Spaniens Politiker haben Vertrauen verspielt
# Text:
# --------------------------------------------------
# Titel: Wer Russlands finstere Absichten erkennen will, der blicke nach Moldau
# Text:
# --------------------------------------------------
# Titel: Die Liebe der Trucker zu Trump
# Text: Am größten Truckstop der Welt an der Interstate 80 gibt es für die meisten Fahrer nur einen Heilsbringer: Donald Trump. Hier in Iowa sehen sie die Welt, wie sie ihnen gefällt, auch wenn es mit der Realität oft nur wenig zu tun hat.
# --------------------------------------------------
# Titel: Nicht die feine englische Art
# Text: Im britischen Unterhaus sitzen so viele neue Abgeordnete wie noch nie. Einige der Neulinge sind mit den teils kuriosen Regeln und Gepflogenheiten überfordert.
# --------------------------------------------------
# Titel: Die Union will zurück zum Atom
# Text: In einem Fünf-Punkte-Papier dekliniert die Bundestagsfraktion ihre Energiepolitik neu – und liebäugelt damit, abgeschaltete Kernkraftwerke wieder in Betrieb zu nehmen.
# --------------------------------------------------
# Titel: Wenn Panzer plötzlich „nachhaltig“ sein sollen
# Text: Aufgrund der wachsenden Bedrohung durch Russland drängen Rüstungsfirmen in nachhaltige Fonds. Verwässert dadurch der Begriff?
# --------------------------------------------------
# Titel: „Viele Väter identifizierten sich immer mehr mit der Erziehung ihrer Kinder“
# Text: Hart arbeitender Familienernährer und zugleich präsenter Papa? Noch immer tun sich viele Männer schwer mit ihrer Rolle bei der Kindererziehung, sagt Luis Teuber – und erklärt, warum es jetzt ein neues Beratungszentrum nur für Papas gibt.
# --------------------------------------------------
# Titel: Wie das Essen in Kitas besser werden soll
# Text:
# --------------------------------------------------
# Titel: „Ich hatte ’ne Kugel im Bein. Warum, das müssen Sie ihn fragen“
# Text:
# --------------------------------------------------
# Titel: Wenn sich der Ozean überschlägt
# Text: Surfer Tim Elter räumt mit den Vorurteilen über seinen Sport auf: die Angst vor der Naturgewalt, die hohen Ziele bei Olympia. Er erklärt, warum er einen Helm trägt und wie er sich verbesserte - indem er beim Triathlon teilnahm.
# --------------------------------------------------
# Titel: Max Verstappen zeigt, dass er den WM-Titel verdient
# Text:
# --------------------------------------------------
# Titel: Eine Nacht auf der Polizeiwache
# Text:
# --------------------------------------------------
# Titel: Und irgendwann ist man plötzlich doch ein Paar
# Text:
# --------------------------------------------------
# Titel: Welcher Steamer macht richtig Dampf?
# Text:
# --------------------------------------------------
# Titel: Wie man Dinge weniger persönlich nimmt
# Text:
# --------------------------------------------------
# Titel: Guilty Pleasures in der Küche
# Text:
# --------------------------------------------------
# Titel: Wie oft sollte man duschen?
# Text:
# --------------------------------------------------
# Titel: „Lesen Sie den Klassenchat mit!“
# Text:
# --------------------------------------------------
# Titel: Sind Geldmarkt-ETFs besser als Tagesgeld?
# Text:
# --------------------------------------------------
# Titel: Acht Wellness-Hotels in Österreich
# Text:
# --------------------------------------------------
# Titel: Zwei Leben
# Text: Als der schwer kranke Norweger Mats Steen mit 25 Jahren stirbt, erfährt seine Familie von seinem Leben im Videospiel „World of Warcraft“. Ein berührender und hoffnungsvoller Film.
# --------------------------------------------------
# Titel: Krieg im Paradies
# Text: 1932 veröffentlichte Arnold Zweig einen Kriminalroman, in dem der Konflikt um Palästina schon in all seiner Komplexität beschrieben ist. Die Zeit für eine Neuauflage hätte nicht besser sein können.
# --------------------------------------------------
# Titel: Affen werden in diesem Universum keinen  Hamlet schreiben
# Text: Es gilt als statistische Binsenweisheit: Wenn Schimpansen nur lange genug wild auf einer Schreibmaschine herumtippen, wird irgendwann Literatur dabei herauskommen. Doch das stimmt nicht.
# --------------------------------------------------
# Titel: „Heilige Scheiße, das war ein Youtube-Moment“
# Text: „Coldplay“-Sänger Chris Martin stürzt auf der Bühne in ein Loch, Königin Camilla will Tabus für Frauen brechen, und Peter Maffay glaubt an Gott – auf Peter-Maffay-Weise.
# --------------------------------------------------
# Titel: „Es gibt einen Unterschied zwischen Bekämpfen und Vertreiben“
# Text: Wie wird man Kleider- und Lebensmittelmotten wieder los? Ein Experte erklärt, welche Hausmittel gegen Kleider- und Lebensmittelmotten wirken und welche nutzlos sind.
# --------------------------------------------------
# Titel: Bauen Sie Zahlenstraßen – kreuz und quer
# Text:
# --------------------------------------------------
# Titel: 15 mal 15 – füllt Ihr Wissen alle Felder?
# Text:
# --------------------------------------------------
# Titel: Bilden Sie Wörter – je weniger, desto besser
# Text:
# --------------------------------------------------
# Titel: Füllen Sie das Quadrat – so, dass alles passt
# Text:
# --------------------------------------------------
# Titel: Sie sind am Zug – mit Tipps vom Großmeister
# Text:
# --------------------------------------------------
# Titel: Vier Bilder, eine Gemeinsamkeit – welche?
# Text:
# --------------------------------------------------
# Titel: Wohin im November?
# Text: Wenn es zu Hause grau und nasskalt wird: Neun Tipps für nicht allzu ferne Reiseziele. Und warum es dort gerade jetzt besonders schön ist.
# --------------------------------------------------
# Titel: "Die Frage ist, ob es glückliche Menschen gibt"
# Text: Was ist ein erfülltes Leben? Irvin D. Yalom gehört zu den angesehensten Psychotherapeuten Amerikas, seine Frau und er waren 65 Jahre verheiratet. Ein Gespräch über Glück, Vergänglichkeit und das, was zuletzt zählt.
# --------------------------------------------------
# Titel: Das Leben nach dem Tod
# Text: Als ihr Vater schwer krank wurde, hatte unsere Autorin mit vielen Gedanken gerechnet – aber nicht mit dem, der sie dann am meisten beschäftigte: Wie schafft man es, die Erinnerung an einen geliebten Menschen lebendig zu halten?
# --------------------------------------------------
# Titel: Welche Version von mir würden Sie daten?
# Text: Hätte man mehr Matches, wenn man sich beim Online-Dating als besonders erfolgreich, sensibel oder wild darstellen würde? Das fragte sich unser Autor und legte drei unterschiedliche Profile von sich an. Das Ergebnis war eindeutig.
# --------------------------------------------------
# Titel: Old Man Trump – Die wirklich wahre Geschichte des größten Lügners von Amerika
# Text:
# --------------------------------------------------
# Titel: Feuerzone
# Text:
# --------------------------------------------------
# Titel: Dämon
# Text:
# --------------------------------------------------
# Titel: Söders Endspiel
# Text:
# --------------------------------------------------
# Titel: German Angst
# Text:
# --------------------------------------------------
# Titel: Wer ist Joni?
# Text:
# --------------------------------------------------
# Titel: Who the f*** is Alice?
# Text:
# --------------------------------------------------
# Titel: Die Mafiaprinzessin
# Text:
# --------------------------------------------------
# Titel: Die Kunst zu stehlen
# Text:
# --------------------------------------------------
# Titel: Vor aller Augen
# Text:
# --------------------------------------------------
# Titel: Inside 1860
# Text:
# --------------------------------------------------
# Titel: 71 Schüsse - Mein Leben nach dem Amoklauf
# Text:
# --------------------------------------------------
# Titel: Going to Ibiza
# Text:
# --------------------------------------------------
# Titel: Deutsche Abgründe
# Text:
# --------------------------------------------------
# Titel: Sie dürfen jetzt klatschen
# Text:
# --------------------------------------------------
# Titel: Wie kaputt ist die Bahn wirklich, Claus Weselsky?
# Text:
# --------------------------------------------------
# Titel: "Lesen Sie den Klassenchat mit!"
# Text:
# --------------------------------------------------
# Titel: Welche Version von mir würden Sie daten?
# Text:
# --------------------------------------------------
# Titel: "Ich empfehle allen Paaren, mal gemeinsam einen Porno zu schauen"
# Text:
# --------------------------------------------------
# Titel: Worauf Paare mit Kinderwunsch achten sollten
# Text:
# --------------------------------------------------
# Titel: "Wenn die Frau gut informiert in die Praxis kommt, gereicht ihr das zum Nachteil"
# Text:
# --------------------------------------------------
# Titel: "Cremes können die Hautalterung definitiv beeinflussen"
# Text:
# --------------------------------------------------
# Titel: "Alarmiert sollten Eltern sein, wenn das Kind nicht mehr zur Schule gehen will"
# Text:
# --------------------------------------------------
# Titel: Warum ich meinem Vater viel zu lange hinterher rannte
# Text:
# --------------------------------------------------
# Titel: Bilder des Tages
# Text: Schönes, Erschreckendes, Absurdes und ganz Alltägliches: Momentaufnahmen aus allen Ecken der Welt, laufend aktualisiert.
# --------------------------------------------------
# Titel: Das sind die besten Natur-Fotografien 2024
# Text:
# --------------------------------------------------
# Titel: Bilder der Woche
# Text:
# --------------------------------------------------
# Titel: Wie Musikclubs ums Überleben kämpfen
# Text: In der Aschaffenburger Altstadt verbirgt sich ein Musikclub, der überregional bekannt ist. Heuer feiert der Colos-Saal 40-jähriges Bestehen. Die Branche kriselt. Doch der Colos-Saal ist optimistisch.
# --------------------------------------------------
# Titel: Staatsanwaltschaft fordert hohe Haftstrafe im Dämonenprozess
# Text:
# --------------------------------------------------
# Titel: Selbst in Bayern wird das Geld knapp
# Text:
# --------------------------------------------------
# Titel: Tag der Entscheidung
# Text: Nach einem harten Wahlkampf entscheiden die Amerikaner, wer ins Weiße Haus einzieht. Donald Trump zeigt sich immer aggressiver, Kamala Harris eröffnen sich im Endspurt überraschende Chancen.
# --------------------------------------------------
# Titel: Wann kommt das Ergebnis?
# Text:
# --------------------------------------------------
# Titel: Was Trump und Harris den Wählern versprechen
# Text:
# --------------------------------------------------
# Titel: Der Staatsanwalt und die Kokainbande
# Text: Als Staatsanwalt brachte er eine berüchtigte Drogenbande hinter Gitter. Jetzt sitzt Yashar G. selbst in U-Haft: wegen des Verdachts auf Bestechlichkeit, Geheimnisverrat, Strafvereitelung. Hätte er den Prozess gegen die Kokainhändler überhaupt führen dürfen?
# --------------------------------------------------
# Titel: Rettungskräfte suchen in Autos und Garagen nach Toten
# Text:
# --------------------------------------------------
# Titel: Mehr Kinder für Putins Reich
# Text:
# --------------------------------------------------
# Titel: Wie sich der „Supermarkt der Welt“ wandelt
# Text: Bei der US-Wahl steht auch das Schicksal der chinesischen Industrie auf dem Spiel. Doch mit Konkurrenzkampf kennen sie sich hier aus.
# --------------------------------------------------
# Titel: Russischer Milliardär zahlt Geldauflage in Millionenhöhe
# Text:
# --------------------------------------------------
# Titel: „Vor allem der Bankensektor untergräbt die Demokratie“
# Text:
# --------------------------------------------------
# Titel: Ampel: Was sich Lindner vom Koalitionsbruch versprechen könnte
# Text:
# --------------------------------------------------
# Titel: „Insel aus Müll“: Der letzte Wahlkampf-Skandal?
# Text:
# --------------------------------------------------
# Titel: Made in Bangladesch: Neue Hoffnung für die Wirtschaft?
# Text:
# --------------------------------------------------
# Titel: Feuerzone - Das System Rammstein und der Machtmissbrauch in der Musik
# Text:
# --------------------------------------------------
# Titel: Dieser Influencerin folgen fast eine Million Menschen
# Text:
# --------------------------------------------------
# Titel: Die Kunst zu stehlen
# Text:
# --------------------------------------------------
# Titel: Lage weiter dramatisch: Unfreundlicher Empfang für spanischen König
# Text: Ein freundlicher Empfang war wohl nicht zu erwarten, nun werfen Betroffene der schlimmen Unwetter vom Dienstag sogar Schlamm in Richtung des Königspaars: Aus Wut über das empfundene Behördenversagen.
# --------------------------------------------------
# Titel: Iran: Frau in Unterwäsche festgenommen
# Text:
# --------------------------------------------------
# Titel: Peru: Blitz schlägt auf Fußballplatz ein
# Text:
# --------------------------------------------------
# Titel: Der Größte
# Text: Mit Lionel Hampton auf Tour fing es an, mit Michael Jacksons „Thriller“ hörte es noch lange nicht auf: Quincy Jones, der wichtigste Musikproduzent des 20. Jahrhunderts, ist tot. Ein Nachruf.
# --------------------------------------------------
# Titel: Öder Ort, guter Name
# Text:
# --------------------------------------------------
# Titel: Eine Wohltat für Frankreichs geistigen Zustand
# Text:
# --------------------------------------------------
# Titel: Wo die Wahrheit ersäuft
# Text: Appelle an die Vernunft gegen ungenierte Alternativerzählungen: Warum der US-Wahlkampf auf Facebook und Truth Social weniger knapp erscheint als in den großen Umfragen.
# --------------------------------------------------
# Titel: In Hochglanz zur Truppe
# Text:
# --------------------------------------------------
# Titel: Realitätsflucht ist abgesagt
# Text:
# --------------------------------------------------
# Titel: Diese Ravioli sind ein Wunder
# Text:
# --------------------------------------------------
# Titel: Fleischbällchen mallorquinische Art
# Text:
# --------------------------------------------------
# Titel: Der Speck muss weg: Die beste vegetarische Carbonara
# Text:
# --------------------------------------------------
# Titel: Stracciatella kommt jetzt in die Suppe
# Text:
# --------------------------------------------------
# Titel: Pasta mit Petersilien-Pesto und Knusper-Kapern
# Text:
# --------------------------------------------------
# Titel: Perfektion in Milch und Mehl
# Text:
# --------------------------------------------------
# Titel: "Unordnung entsteht durch aufgeschobene Entscheidungen"
# Text:
# --------------------------------------------------
# Titel: "Kochen ist für uns Italienerinnen und Italiener eine Religion"
# Text:
# --------------------------------------------------
# Titel: "An der bangladeschischen Küche liebe ich am allermeisten, dass nichts verschwendet wird"
# Text:
# --------------------------------------------------
# Titel: "Ich rate den Leuten: Geht zum Discounter!"
# Text:
# --------------------------------------------------
# Titel: Im Schneckentempo
# Text: Hoffnung und Fortschritt am Anfang, Frustration und Chaos zum Schluss: Die UN-Weltnaturkonferenz COP16 in Cali hinterlässt ein zwiespältiges Bild. Das Wichtigste im Überblick.
# --------------------------------------------------
# Titel: Naschen nette Menschen besonders gerne Süßes?
# Text:
# --------------------------------------------------
# Titel: Weltnaturkonferenz endet ohne Einigung zu Finanzierung
# Text:
# --------------------------------------------------
# Titel: Stürzen Sie im Traum auch manchmal in die Tiefe? Dann lesen Sie dieses Interview!
# Text: Albträume wie den Falltraum sollte man nicht ignorieren, sagt Experte Michael Schredl. Hier erklärt er, was wir aus unseren Albträumen über uns lernen können – und wie man ihnen verblüffend einfach ein Happy End verpasst.
# --------------------------------------------------
# Titel: „Vielleicht kann oder traut sich nicht jeder, bei einem blutenden Menschen zu helfen“
# Text:
# --------------------------------------------------
# Titel: Wenig Zucker für Kinder schützt sie im späteren Leben vor chronischen Krankheiten
# Text:
# --------------------------------------------------
# Titel: Wohin im November?
# Text: Wenn es zu Hause grau und nasskalt wird: Neun Tipps für nicht allzu ferne Reiseziele. Und warum es dort gerade jetzt besonders schön ist.
# --------------------------------------------------
# Titel: Achterbahn im Eichenwald
# Text:
# --------------------------------------------------
# Titel: Kurz nach ... Utrecht
# Text:
# --------------------------------------------------
# Titel: Das Geheimnis von Cupra
# Text: Dem VW-Konzern geht es schlecht, die spanische Tochtermarke allerdings ist erstaunlich erfolgreich. Das liegt vor allem an einer Zielgruppe, die sie raffiniert anspricht.
# --------------------------------------------------
# Titel: Zäh am Berg
# Text:
# --------------------------------------------------
# Titel: „Das fühlt sich an wie fliegen, Alter!“
# Text:
# --------------------------------------------------
# Titel: Als die Verfassung auf der Kippe stand
# Text: Die Wahl des amerikanischen Präsidenten durch das Electoral College ist heute höchst umstritten – viele halten das System, das nun wieder Donald Trump begünstigen dürfte, für ungerecht. Doch die Ursprünge gehen zurück in die Gründungsphase der USA.
# --------------------------------------------------
# Titel: „Wir brauchen keine Männer mehr, die den Frauen ihren Körper erklären“
# Text:
# --------------------------------------------------
# Titel: „Ich habe viel Energie, die muss irgendwohin“
# Text:
# --------------------------------------------------
# Titel: „Die Pommes sind ein Discounter-Produkt und mein Testsieger“
# Text: Mit Ketchup, zur Currywurst oder einfach pur: Pommes frites sind beliebt. Doch welches Produkt aus dem Supermarkt schmeckt am besten? Ein Imbissbetreiber hat neun Marken getestet.
# --------------------------------------------------
# Titel: „Jeder auf der Welt sollte ein Recht auf gutes, faires Essen haben“
# Text:
# --------------------------------------------------
# Titel: Wer soll das bezahlen?
# Text:
# --------------------------------------------------
# Titel: Gleichberechtigung auf der Toilette!
# Text:
# --------------------------------------------------
# Titel: „Beim 20. Mal lässt auch das Brennen nach“
# Text:
# --------------------------------------------------
# Titel: Wenn der Gedanke an die Zukunft Panik auslöst
# Text:
# --------------------------------------------------
# Titel: „Beim ersten Date habe ich erfahren, dass sie verheiratet ist“
# Text:
# --------------------------------------------------
# Titel: „Sorryyy, aber könnt ihr ein bisschen leiser sein?“
# Text:
# --------------------------------------------------
# Titel: „Wir sind blauäugig in diese Ehe gegangen“
# Text:
# --------------------------------------------------
# Titel: Das späte erste Mal
# Text:
# --------------------------------------------------
# Titel: Muss man mit 30 wissen, was man will?
# Text:
# --------------------------------------------------
# Titel: "Es ist klar, dass sich das Leben durch Kinder verändern wird"
# Text:
# --------------------------------------------------
# Titel: DOK Leipzig 2024 mit Publikumsrekord
# Text:
# --------------------------------------------------
# Titel: Olympia 2026 im Blick: Deutschland Cup als Schaufenster
# Text:
# --------------------------------------------------
# Titel: Zwei Männer durch Schusswaffen schwer verletzt
# Text:
# --------------------------------------------------
# Titel: Mit Radkreuz und Softairpistole - drei Verletzte bei Streit
# Text:
# --------------------------------------------------
# Titel: Frau liegt blutend im Treppenhaus - Ermittlung in Todesfall
# Text:
# --------------------------------------------------
# Titel: Frankfurter Flughafen erholt sich schleppend von Pandemie
# Text:
# --------------------------------------------------
# Titel: Vier Palästinenser bei Einsätzen im Westjordanland getötet
# Text:
# --------------------------------------------------
# Titel: Mix aus sonnig und neblig-trüb in NRW bis zum Wochenende
# Text:
# --------------------------------------------------
# Titel: „Ruhm den Helden! Tod den Feinden!“
# Text: Drei Tauchlehrer aus der Ukraine sollen an der Sprengung der Nord-Stream-Pipelines beteiligt gewesen sein, gegen einen erlässt der Generalbundesanwalt sogar Haftbefehl. Warum der Fall nun endgültig zum Politikum wird.
# --------------------------------------------------
# Titel: Ernstfall
# Text: Die Bundesregierung rüstet sich für ein Schreckensszenario: die Wiederkehr Donald Trumps ins Weiße Haus. Auf dem Spiel stehen Europas Sicherheit und Wohlstand. Gesucht wird eine Gebrauchsanweisung für Trump.
# --------------------------------------------------
# Titel: Weltherrschaft, Taylor's Version
# Text: Wer in diesen düsteren Zeiten die destillierte Freude sucht, findet sie bei Taylor Swift. Über den unerhörten Sog des derzeit größten Popstars - und den klug konstruierten Zauber ihrer Songs.
# --------------------------------------------------
# Titel: Wie die AfD die politische Debatte vergiftet
# Text: Björn Höcke ist wegen der Verwendung von NS-Parolen verurteilt worden. Die SZ hat untersucht, wie er und die AfD im Thüringer Landtag mit rechter Sprache Politik machen.
# --------------------------------------------------
# Titel: Wie Sie gesund Gewicht verlieren
# Text:
# --------------------------------------------------
# Titel: Ratgeber Erziehung
# Text:
# --------------------------------------------------
# Titel: Den Nachlass so regeln, wie man will
# Text:
# --------------------------------------------------
# Titel: So bekommen Sie mehr Gehalt
# Text:
# --------------------------------------------------
# Titel: Dürften Sie deutscher Staatsbürger werden?
# Text:
# --------------------------------------------------
# Titel: Tipps für das Leben an der Universität
# Text:
# --------------------------------------------------
# Titel: Der Grippe entkommen
# Text:
# --------------------------------------------------
# Titel: Wege aus der Melancholie
# Text:
# --------------------------------------------------
# Titel: Bauen Sie Zahlenstraßen – kreuz und quer
# Text: Eine smarte Weiterentwicklung des Sudoku: Hier gibt es auch schwarze Felder – und dazwischen sind lückenlose Zahlenfolgen zu verstauen. Bekommen Sie’s auf die Reihe?
# --------------------------------------------------
# Titel: 15 mal 15 – füllt Ihr Wissen alle Felder?
# Text:
# --------------------------------------------------
# Titel: Bilden Sie Wörter – je weniger, desto besser
# Text:
# --------------------------------------------------
# Titel: Bauen Sie Zahlenstraßen – kreuz und quer
# Text:
# --------------------------------------------------
# Titel: Füllen Sie das Quadrat – so, dass alles passt
# Text:
# --------------------------------------------------
# Titel: Sie sind am Zug – mit Tipps vom Großmeister
# Text:
# --------------------------------------------------
# Titel: Vier Bilder, eine Gemeinsamkeit – welche?
# Text:
# --------------------------------------------------
# Titel: Juwelen mit Suchtgefahr
# Text:
# --------------------------------------------------
# Titel: Der Legespiel-Klassiker aus China
# Text:
# --------------------------------------------------
# Titel: Das Logikrätsel auf 9 x 9 Feldern
# Text:
# --------------------------------------------------
# Titel: Der Computerspiel-Klassiker
# Text:
# --------------------------------------------------
# Titel: Mit Kanonen auf Seifenblasen
# Text:
# --------------------------------------------------
# Titel: Das Kult-Rätsel aus dem SZ-Magazin
# Text:
# --------------------------------------------------
# Titel: Wie hoch ist Ihr Intelligenzquotient?
# Text:
# --------------------------------------------------
# Titel: Alle Jahre wieder – das große Gewinnspiel
# Text:
# --------------------------------------------------
# Titel: Schaffen Sie die Prüfung noch?
# Text:
# --------------------------------------------------
# Titel: Dürften Sie deutscher Staatsbürger werden?
# Text:
# --------------------------------------------------
# Titel: Testen Sie Ihre emotionale Intelligenz
# Text:
# --------------------------------------------------
# 186

# %% [markdown]
# ## HTML Analysis for Welt

# %%
all_path_to_welt[0]
# Out:
# '/Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/input/data-lake_2024_11/2024-11-27-welt.html'

# %%
with open(all_path_to_welt[0], "r") as f:
    html = f.read()

# %%
bs = BeautifulSoup(html, "html.parser")

# %%
articles = bs.find_all("article")

for article in articles:
    # Titel suchen (Klasse .c-teaser__headline)
    title_element = article.select_one('.c-teaser__headline')
    title = title_element.get_text(strip=True) if title_element else " "
    
    # Text suchen (Klasse .c-teaser__intro)
    text_element = article.select_one('.c-teaser__intro')
    text = text_element.get_text(strip=True) if text_element else " "

    # Ausgabe der Ergebnisse
    print("Titel:", title)
    print("Text:", text)
    print("-" * 50)
print(len(articles))
# Out:
# Titel: Die Mammutpläne der Bahn – und die Realität
# Text: 2025 soll die wichtige Strecke Hamburg-Berlin innerhalb von neun Monaten saniert werden. Die Ausgaben drohten deutlich teurer zu werden, als der ursprüngliche Plan vorsah. Nach dem Ampel-Aus ist zudem das Geld knapp. Doch wo wird gespart – und welche Folgen hat das?
# --------------------------------------------------
# Titel: SPD und BSW einigen sich auf Koalitionsvertrag in Brandenburg
# Text:
# --------------------------------------------------
# Titel: „Bedarf auf Jahre gedeckt“, sagt Kubicki über Grüne – Thüringens CDU-Chef fürchtet Kemmerich-Moment
# Text:
# --------------------------------------------------
# Titel: „Auf absolutem Tiefpunkt“ – Mit Pistorius stünde die SPD bei 21 Prozent, sagt der Forsa-Chef
# Text:
# --------------------------------------------------
# Titel: „Wir richten uns ein“ – 65 Prozent der Ukrainer wollen bleiben, sagt der Behördenchef
# Text:
# --------------------------------------------------
# Titel: 31-Jähriger in Berlin getötet – Zeugen berichten von mehreren Schüssen und Blut auf der Straße
# Text:
# --------------------------------------------------
# Titel: „14 Jahre sind weg“ – Justizopfer verklagt Freistaat Bayern auf 750.000 Euro
# Text:
# --------------------------------------------------
# Titel: Warum der „1701 Plus“-Deal ein Erfolg für Israels aggressive Strategie ist
# Text: Israel und Libanon haben sich auf eine Waffenruhe verständigt. Das Abkommen bedeutet eine teilweise Niederlage für die Hisbollah und eine Zäsur für die Region. Und nun zeigt sich auch, dass sich viele Kritiker Israels getäuscht hatten.
# --------------------------------------------------
# Titel: Waffenruhe zwischen Israel und Hisbollah in Kraft – auch Hamas offenbar bereit für Feuerpause
# Text: Der Waffenstillstand scheint zu halten – nachdem beide Seiten kurz vor Inkrafttreten ihre Angriffe noch einmal intensiviert hatten. Netanjahu behält sich neue Attacken vor, sollte die Gegenseite provozieren. Auch die Hamas erklärt offenbar seine Bereitschaft für eine Waffenruhe im Gazastreifen
# --------------------------------------------------
# Titel: Israel verkündet Waffenruhe mit Hisbollah – Alle Reaktionen
# Text: Nach mehr als einem Jahr heftiger Angriffe aus dem Libanon will Israel den heißen Krieg mit der Hisbollah beenden. Premierminister Benjamin Netanjahu sprach sich für eine Waffenruhe aus. Sehen Sie diese und weitere Nachrichten bei WELT TV.
# --------------------------------------------------
# Titel: Kanzlerkandidat Merz? „Ich gönne ihm das“, sagt die Pop-Literatin Angela Merkel
# Text: Im Deutschen Theater in Berlin hat die frühere Bundeskanzlerin ihre Memoiren vorgestellt. Für Angela Merkel fügt sich ihre Politik wie gehabt alternativlos zusammen. Sie bereut nichts. Eine Zumutung war immer nur die Realität, nie ihre Politik.
# --------------------------------------------------
# Titel: „Outsider“ – Ex-Kandidat Peer Steinbrück gibt seiner SPD und Scholz kaum noch Chancen
# Text: Im Einzelinterview mit Sandra Maischberger äußert sich der SPD-Politiker Peer Steinbrück spöttisch über die Union. Einen Sieg seiner Partei im Februar hält er trotzdem für unwahrscheinlich. Der Generalinspekteur der Bundeswehr warnt derweil, Deutschland müsse sich bis 2029 gegen Russland wehren können
# --------------------------------------------------
# Titel: Die Frage, wie lang der Plan der kontrollierten Eskalation noch aufgeht
# Text: Das Kriegsgeschehen in der Ukraine scheint eine neue Eskalationsstufe erreicht zu haben. Noch folgen die Akteure einem definierten strategischen nuklearen Ablaufplan. Beide Seiten streben damit ein Ziel an, das bei künftigen Verhandlungen relevant werden könnte.
# --------------------------------------------------
# Titel: Niedersachsens bemerkenswerte Wasser-Wende
# Text: Das Agrarland Niedersachsen meldet eine drastisch sinkende Nitratkonzentration im Sickerwasser. Der überraschende Erfolg im Umweltschutz macht Landwirten jetzt Zuversicht für den Abbau von belastender Bürokratie und Kosten – doch die Hoffnung könnte verfrüht sein.
# --------------------------------------------------
# Titel: Mit dem Vorsprung durch Technik ist es vorbei
# Text: Die deutsche Autoindustrie ist in der Krise. China profitiert von den radikalen Umwälzungen durch Elektromobilität und krempelt den Weltmarkt um. Aber es gibt positive Entwicklungen aus Sicht heimischer Unternehmen. Und Deutschland hat einen großen Vorteil.
# --------------------------------------------------
# Titel: Problemkind der Energiewende – Was der Wärmepumpe für den Durchbruch fehlt
# Text: 2024 wird das Einbau-Ziel von 500.000 Wärmepumpen weit verfehlt. Die Verbraucher seien verunsichert, beklagt die Branche und gibt eine Prognose ab, wann der Zielwert erreicht werden könnte. Weil der Einbau-Zuschuss offenbar nicht reicht, fordern sie zudem die nächste Förderung.
# --------------------------------------------------
# Titel: Wo das Hochhaus noch eine Zukunft hat – und wo nicht
# Text: Hochhäuser sind für die einen der Ausweg aus der Baukrise, für die anderen einfach nur teuer und wenig nachhaltig. Ein Architekturexperte sieht die Zukunft vor allem auf einem Kontinent. Bald würden dort Städte nach chinesischem Vorbild entstehen.
# --------------------------------------------------
# Titel: „Es ist ein lautes Lachen über ein müdes System“
# Text: Über die von Maurizio Cattelan an die Wand geklebte Banane, die für 6,2 Millionen Dollar versteigert wurde, wundert sich die Welt. Eine Unverschämtheit? Die Veralberung des Markts? Jetzt erklärt der Künstler sein Werk und warum er froh ist, dass es nicht bei Elon Musk gelandet ist.
# --------------------------------------------------
# Titel: „Ich hatte in meiner Kindheit ein traumatisches Erlebnis. Muss mein Mann das wissen?“
# Text: Wer früh im Leben traumatische Erlebnisse hatte, ist oft mit Scham behaftet und spricht nicht unbedingt darüber – auch nicht mit dem eigenen Partner. Doch was sollte man dem Menschen an seiner Seite sagen? Und was vielleicht auch nicht?
# --------------------------------------------------
# Titel: „Dieser kleine Prozess verbrennt 100 Kalorien zusätzlich pro Tag“
# Text: Effektiv und nachhaltig Gewicht zu verlieren, ohne auf etwas verzichten zu müssen, ist das Motto seiner Arbeit. Hier erklärt Experte Simon Mathis, diplomierter Fitnesstrainer und Ernährungsberater, welche die besten Hebel für nachhaltiges Abnehmen sind.
# --------------------------------------------------
# Titel: In Freiburgs Altstadt überstand nur das Münster die mehr als 1700 Tonnen Bomben
# Text: Laut Gerüchten aus dem Zweiten Weltkrieg sollte die Universitätsstadt am Schwarzwald nicht zerstört werden, weil dort viele Lazarette lagen. Oder weil dort nach Kriegsende die Alliierten Quartier nehmen wollten. Am 27. November 1944 beendete die „Operation Tigerfish“ alle Spekulationen.
# --------------------------------------------------
# Titel: Jetzt kommt der Vorstoß, „Politikerbeleidigung“ umfassender zu ahnden
# Text: Aus der SPD kommt eine Initiative, die Voraussetzungen der „Politikerbeleidigung“ abzusenken, um die Strafverfolgung zu vereinfachen. Niedersachsen möchte einen entsprechenden Antrag auf der kommenden Justizministerkonferenz einbringen. Ein Verfassungsjurist warnt vor einem Verstoß gegen das Grundgesetz.
# --------------------------------------------------
# Titel: Warum die Pflegeheime immer teurer werden
# Text: Der Eigenanteil für Seniorenheime hat teils drastisch zugenommen. Doch Fachverbände warnen bereits vor weiteren Anstiegen. Das bedeutet nicht nur eine wachsende Belastung für Betroffene und Angehörige – ein Kostenpunkt birgt auch politischen Sprengstoff.
# --------------------------------------------------
# Titel: Warum Söder jetzt seine antigrüne Haltung aufweicht
# Text: Vor Kurzem war ein Bündnis mit den Grünen für CSU-Chef Söder noch ein „absolutes No-Go“. Doch jetzt schlägt er andere Töne an, die denen von Unions-Kanzlerkandidat Merz ähneln. So kritikwürdig sein Wankelmut ist: Pragmatismus wiegt in dieser politischen Lage schwerer.
# --------------------------------------------------
# Titel: Schützen Sie Ihr Vermögen – so werden Sie in 90 Minuten zum Erb-Experten!
# Text: Jedes Jahr vererben die Deutschen ein Vermögen mit dreistelligem Milliardenwert, Tendenz steigend. Auch die Erbschaftsstreitigkeiten nehmen zu. WELT macht Sie fit zu diesem Thema. Buchen Sie hier einen 90-minütigen Kurs für einen Bruchteil dessen, was in einer Kanzlei an Gebühr fällig wird.
# --------------------------------------------------
# Titel: Die bislang unentdeckten Spuren der Nord-Stream-Sabotage
# Text: Bei der Zerstörung der Nord-Stream-Pipelines nutzten die Saboteure nur vier Sprengsätze – so dachte man bisher. Tatsächlich waren es mindestens sechs. Das zeigen WELT vorliegende Gerichtsakten und eine Sonaraufnahme. Die Erkenntnisse nähren Zweifel an einer These über die Auftraggeber des Anschlags.
# --------------------------------------------------
# Titel: Caren Miosga zeigt, dass der ÖRR nicht reformierbar ist
# Text: In ihrem Sonntagabend-Talk verliert Caren Miosga jegliche journalistische Distanz und schmachtet ihren Gast Robert Habeck regelrecht an. Das ist sogar dem sonst um keine Schwurbelei verlegenen Grünen-Politiker unangenehm. Aber zumindest für eines war diese Sendung gut.
# --------------------------------------------------
# Titel: „Im Handel verändert KI das Kundenverhalten“
# Text: KI verändert jede Industrieform, sagt Dr. Karsten Wildberger, CEO der MediaMarktSaturn am Rande des WELT KI-Gipfels. Man müsse sich im Handel fragen, wie „möchte der Kunde in Zukunft einkaufen“. Mit seinem persönlichen KI-Assistenten möglicherweise, der ein Erstgespräch führt. Im Handel komme es dann aber auf die „menschliche Komponente“ an. Und auf die wolle sein Unternehmen sich fokussieren.
# --------------------------------------------------
# Titel: Israelische Armee vermeldet Tötung eines hochrangigen Hamas-Scharfschützen
# Text:
# --------------------------------------------------
# Titel: Nächster Doppelpack – Wirtz spielt überragend bei Leverkusens Kantersieg gegen Salzburg
# Text:
# --------------------------------------------------
# Titel: Erfolg aus Karlsruhe – Deutsches KI-Start-up Black Forest Lab soll eine Milliarde Dollar wert sein
# Text:
# --------------------------------------------------
# Titel: CDU-Spitze widerspricht Merkel bei Atomkraft
# Text:
# --------------------------------------------------
# Titel: Er soll Hochschulabschlüsse gefälscht haben – Wohnung von AfD-Politiker durchsucht
# Text:
# --------------------------------------------------
# Titel: EU-Parlament diskutiert striktes Rauchverbot fast überall im Freien
# Text:
# --------------------------------------------------
# Titel: Jetzt im Fernsehen
# Text:
# --------------------------------------------------
# Titel: Gefahr „anhaltend hoch“ – BKA warnt vor Anschlägen auf Weihnachtsmärkte
# Text:
# --------------------------------------------------
# Titel: Mindestens zwei Tote nach russischem Beschuss von Sumy
# Text:
# --------------------------------------------------
# Titel: „Dauer der Waffenruhe hängt davon ab, was im Libanon geschieht“, warnt Netanjahu
# Text:
# --------------------------------------------------
# Titel: So verteidigt Merkel ihr „Wir schaffen das“
# Text:
# --------------------------------------------------
# Titel: Nach Untergang von Touristen-Boot – Vier Todesopfer geborgen
# Text:
# --------------------------------------------------
# Titel: Nach Absturz in Litauen bergen Ermittler den Flugschreiber
# Text:
# --------------------------------------------------
# Titel: Grüne Wirtschaftswende? – „Märchenerzählungen müssen beendet werden“
# Text:
# --------------------------------------------------
# Titel: „Subventionitis von oben funktioniert nicht“
# Text:
# --------------------------------------------------
# Titel: „Problematisch“ – Wirtschaftsweise Grimm rechnet mit Habecks Förder-Politik ab
# Text:
# --------------------------------------------------
# Titel: „Angela Merkel zeigt eine elefantöse Unfähigkeit zur Selbstkritik“
# Text:
# --------------------------------------------------
# Titel: Hisbollah-Waffenruhe „in greifbarer Nähe“, sagt Baerbock
# Text:
# --------------------------------------------------
# Titel: „Sechs statt vier Bomben" ließen Nord-Stream-Leitungen explodieren
# Text:
# --------------------------------------------------
# Titel: Ehe-Seminar in Moschee – „Mit 13 Jahren denkt man nicht an eine Eheschließung“
# Text:
# --------------------------------------------------
# Titel: „Wenn die Grünen weiter an der Regierung bleiben, überleben wir das nicht“
# Text:
# --------------------------------------------------
# Titel: Ein stiller Pionier der Gemüseküche
# Text: Ohne sich selbst in den Vordergrund zu drängen, hat Alan Micks in Berlin eine innovative Gemüseküche entwickelt – mit Anleihen bei den deftigen Wirtshausklassikern aus seiner irischen Heimat. Seine Standards haben sich mittlerweile über die Hauptstadt hinaus etabliert.
# --------------------------------------------------
# Titel: „Menschen, die die Trennung nicht schaffen, haben meistens gute Gründe dafür“
# Text: Warum bleiben Menschen in einer Beziehung, obwohl sie über eine Trennung nachdenken? Manche scheuen die Entscheidung, andere fühlen sich „abhängig“ von der Nähe: Romantische Liebe und Sucht – gar nicht so verschieden, stellen Wissenschaftler fest und spüren den ambivalenten Gefühlen nach.
# --------------------------------------------------
# Titel: Skifahren und Surfen – in Kalifornien geht beides
# Text: Der US-Bundesstaat ist berühmt für seine Strände, vor denen man wunderbar wellenreiten kann. Aber es gibt in den Bergen auch famose Pisten, die locker mit den Alpen mithalten können. Der Winter ist eine gute Zeit, um beides in einem Urlaub miteinander zu verbinden.
# --------------------------------------------------
# Titel: Horst Seehofer kommt „sehr schlecht weg“ – Die wichtigsten Aussagen aus Merkels Memoiren
# Text: 16 Jahre hat sie Deutschland regiert und auch die Geschicke der Welt mit beeinflusst. Nun legt Angela Merkel ihre Erinnerungen als Buch vor. Was sie über Putin, Trump und Schröder zu berichten weiß.
# --------------------------------------------------
# Titel: So viel Betrug bei Corona-Tests wurde bis jetzt entdeckt
# Text: Seit 2021 prüfen die Kassenärztlichen Vereinigungen die Abrechnungen der Corona-Testzentren. Das führte bereits zu Rückzahlungen in Millionenhöhe sowie dutzenden Strafanzeigen. Doch die zurückgeforderten Summen bleiben bislang deutlich hinter den Erwartungen des Bundeskriminalamts zurück.
# --------------------------------------------------
# Titel: Der Feminismus ist am Arsch
# Text: Deutschlands Vorzeige-Feministinnen wollen gar keine Verbesserungen für Frauen. Ihnen geht es um Sprechakte und Buchverkäufe – Hauptsache, irgendwie pink oder trans. Politik, Medien und Wirtschaft machen mit. Und wer das als Frau kritisiert, steht schnell am Pranger.
# --------------------------------------------------
# Titel: Rotwein-Fleck? Diesen Fehler sollten Sie auf keinen Fall machen
# Text: Das Malheur ist schnell passiert: Ein Tropfen Rotwein auf Kleidung oder Teppich. Doch was ist die beste Strategie, um den Fleck zu entfernen? Diesen und viele weitere hilfreiche Tipps bekommen Sie von unserer Künstlichen Intelligenz.
# --------------------------------------------------
# Titel: „Warum kann er beim Sex mit mir nicht kommen?“
# Text: Er hat Probleme, zum Orgasmus zu kommen – vor allem mit seiner Freundin. Darüber zu sprechen fällt ihm schwer. Sie ist ratlos und stellt sich selbst infrage. Woran das liegt und wie Paare da wieder rauskommen, weiß die Sexologin.
# --------------------------------------------------
# Titel: Wie das Immunsystem unsere Stimmung beeinflusst
# Text: Chronischer Stress und anhaltende psychische Belastungen schwächen das Immunsystem – das ist bekannt. Doch unser Immunsystem kann umgekehrt auch unsere Psyche beeinflussen. Wie stark diese Verbindung ist und welche Auswirkungen sie auf unser Verhalten und unsere mentale Gesundheit hat.
# --------------------------------------------------
# Titel: Wann es Zeit wird, eine Psychotherapie zu beenden
# Text: „In Therapie gehen“, das tun immer mehr Menschen in Deutschland. Seit Jahren steigen die Krankschreibungen wegen psychischer Erkrankungen, die Wartelisten für Therapieplätze sind lang. Was eine gute Therapie ausmacht – und von welchen Erwartungen man abrücken sollte.
# --------------------------------------------------
# Titel: Ein Viertel der Erwachsenen in Deutschland leidet unter Depression
# Text: 45 Prozent der Deutschen sind direkt oder indirekt von Depression betroffen. Das geht aus einer aktuellen Umfrage hervor, die außerdem zeigt, dass die Familie eine wichtige Rolle spielt. Aber Angehörige sind mitunter überfordert.
# --------------------------------------------------
# Titel: Die Verteidigung des Abendlandes zu Weihnachten
# Text: Gnadenloser Kulturkampf, aber mit Glitzer: Im Winter steht die Koalition aus Linken und Islamisten verloren auf den kalten Straßen. Diese Schwäche sollte die bürgerliche Zivilgesellschaft glühweinwarm nutzen.
# --------------------------------------------------
# Titel: „Nackte-Kanone“-Macher im Alter von 80 Jahren gestorben
# Text: Er schrieb das Drehbuch für die „Nackte Kanone“ und führte bei „Hot Shots“ Regie. Jetzt ist Jim Abrahams im Alter von 80 Jahren gestorben. Mit rührenden Worten verabschieden sich ehemalige Weggefährten von der Gag-Koryphäe.
# --------------------------------------------------
# Titel: Bonhoeffer war eben ziemlich woke
# Text: Wie wird ein im KZ ermordeter Theologe zum Säulenheiligen rechter amerikanischer Christen? Der Film „Bonhoeffer: Pastor. Spion. Attentäter“ ist nur die Spitze des Eisberges. Gefährlich ist der Streifen aus einem Grund dennoch nicht.
# --------------------------------------------------
# Titel: „Deutschland ist in vielen Fragen ein Vierteljahrhundert hinter der Zeit“
# Text: Er ist einer der streitbarsten Publizisten unseres Landes. In seiner Frankfurter Kanzlei erklärt Michel Friedman, warum Dissens überlebenswichtig für die Demokratie ist und wir eine neue Aufklärung für das 21. Jahrhundert brauchen.
# --------------------------------------------------
# Titel: Die Wirklichkeit endet in schierer Gewaltexplosion
# Text: War das 17. Jahrhundert wirklich ein „Goldenes Zeitalter“ für die Niederlande? Eine Ausstellung um Rembrandt und andere Barockmeister in Frankfurt zeigt nun, was die Epoche auch war: brutal, gewalttätig, schockierend.
# --------------------------------------------------
# Titel: Sich mit Fallschirmen zu retten, war unter den „Rittern der Lüfte“ lange verpönt
# Text: Im Ersten Weltkrieg sollten Piloten ihre Maschinen um jeden Preis landen, auch wenn sie beschädigt waren oder sie selbst verwundet.  Aber als der Blutzoll unter den stolzen Jagdfliegern ins Unerträgliche stieg, akzeptierten sie die Rettung per Fallschirm – der damals noch nicht ausgereift war.
# --------------------------------------------------
# Titel: Als die „afrikanische Lösung“ misslang, mussten belgische Fallschirmjäger helfen
# Text: Regelmäßig blickt WELTGeschichte auf Schlagzeilen, die WELT im Laufe der Jahrzehnte veröffentlicht hat – und berichtet, was weiter geschah. Heute: die große Rettung von Europäern im Kongo Ende November 1964.
# --------------------------------------------------
# Titel: Desaster unter dem Regenbogen
# Text: 2025 jähren sich die Bauernkriege von 1525 zum 500. Mal. Ihre Deutung hängt von der jeweiligen Gegenwart ab. Oft sagen solche Interpretationen mindestens so viel über die Zeit aus, in der sie entstanden, wie über das geschilderte Ereignis. Das zeigt der Blick auf neue wie alte Bücher zum Thema.
# --------------------------------------------------
# Titel: Trumps Zoll-Eigentor
# Text: Donald Trump will am ersten Tag im Amt hohe Zölle auf Produkte aus Mexiko und Kanada einführen. Die eigene Autoindustrie dürfte das hart treffen – ein beliebtes Fahrzeug wird zu hohem Anteil in den beiden Ländern produziert. Einem deutschen Hersteller empfiehlt ein Analyst den US-Rückzug.
# --------------------------------------------------
# Titel: Die Folgen des Zoll-Zorns und die Aktie für die Babyboom-Kombi
# Text: In der heutigen Folge von „Alles auf Aktien“ sprechen die Finanzjournalisten Anja Ettel und Holger Zschäpitz über die Fettweg-Enttäuschung bei Amgen, süße Gewinne für JM Smucker und klingelnde Kassen bei Novo Nordisk und Eli Lilly.
# --------------------------------------------------
# Titel: Wie Armenien plötzlich zum überragenden Gold-Exporteur wurde
# Text: Trotz Sanktionen gelangt das drittwichtigste Exportgut Russlands weiter in großen Mengen in die Welt. Ein kleines Land ist zu Putins wichtigstem Gold-Zwischenhändler aufgestiegen – und macht ein Milliardengeschäft. Für den Außenhandel hat das verrückte Folgen.
# --------------------------------------------------
# Titel: Ringen um Europas Handels-Chance – siegt Macron erneut über Scholz?
# Text: Seit Jahren verhandeln Europa und Südamerika über ein Freihandelsabkommen. Im Dezember will Brüssel den Deal abschließen. Während Scholz damit den deutschen Auto- und Maschinenbauern helfen will, versucht Paris, den Pakt zu stoppen. Für Europa steht strategisch viel auf dem Spiel.
# --------------------------------------------------
# Titel: Rallye oder Langeweile – Was schafft der Dax noch?
# Text: Der Deutsche Aktienindex ist in diesem Jahr bereits mehr als 15 Prozent gestiegen. Die beiden Wirtschaftsjournalisten Dietmar Deffner und Holger Zschäpitz streiten darüber, ob die Jahresendrallye in diesem Jahr ausfällt.
# --------------------------------------------------
# Titel: „Steuergelder sollten dann nicht Demokratiefeinden zugutekommen“
# Text: 130 Millionen Euro will Berlin 2025 im Kulturbereich sparen – ein starker Einschnitt. Opposition und Kulturszene protestieren wütend, auch gegen Kultursenator Joe Chialo (CDU) persönlich. Er sieht im Sparkurs eine „Chance“ – nötig sei aber eine „Bereitschaft, die in der Privatwirtschaft sehr ausgeprägt ist“.
# --------------------------------------------------
# Titel: Mit dieser Taktik zieht die CDU in den Bundestagswahlkampf
# Text: „Wir schauen nur auf uns“: Der CDU-Plan für den Bundestagswahlkampf 2025 steht: Den Bürgern stellt die Partei von Friedrich Merz dabei ein „Sofortprogramm“ für das erste Vierteljahr nach einer Regierungsübernahme in Aussicht. Eines will sie unbedingt vermeiden.
# --------------------------------------------------
# Titel: Das bedeutet die Waffenruhe zwischen Israel und Hisbollah für den Nahost-Krieg
# Text: Am Abend hat der israelische Sicherheitsrat eine Waffenruhe mit der libanesischen Terrororganisation Hisbollah gebilligt. Wie geht es nun weiter im Krieg im Nahen Osten? Außerdem blicken wir auf die Wahlkampf-Strategie der Union.
# --------------------------------------------------
# Titel: „Ein klares Zeichen von Verzweiflung und typisch für Putins Strategie“
# Text: In Italien beraten die G-7-Außenminister über ihre Ukraine-Strategie. Großbritanniens Außenminister äußert sich besorgt über die jüngste Eskalation im Krieg und wirbt für Sicherheitsgarantien. Und er bezieht Stellung zu Berichten über die Entsendung britischer Truppen in die Ukraine.
# --------------------------------------------------
# Titel: Höcke lobt Artikel mit nationalsozialistischer Karikatur aus SS-Zeitung
# Text: Der AfD-Politiker Björn Höcke verbreitet einen Artikel, der es in sich hat: antisemitische Codes und eine Karikatur eines nationalsozialistischen Cartoonisten, die Amerika als Monster darstellt und 1944 in einer Zeitung der SS erschienen ist. Wie reagiert er auf eine Anfrage dazu?
# --------------------------------------------------
# Titel: Und dann: Russland. Hier musste die Kunst der Kanzlerin versagen
# Text: Was bleibt von Angela Merkel? Das Fremdeln mit der CDU? Die Energiewende, die Flüchtlingskrise? Die Altkanzlerin hat ein Buch geschrieben, das man Merkel-Hassern zur Lektüre nur empfehlen kann. Am aufschlussreichsten sind ihre Sinneswandel, über die sie kaum ein Wort verliert.
# --------------------------------------------------
# Titel: „Können noch ein, zwei Tore mehr schießen“ – Bayern feiert dominanten Sieg gegen PSG
# Text: Der FC Bayern feiert gegen Paris Saint-Germain einen wichtigen Sieg. Der Rekordmeister klettert in der Tabelle der Champions League weiter nach oben. Die Bayern-Fans protestieren derweil gegen PSG-Boss Nasser Al-Khelaifi.
# --------------------------------------------------
# Titel: Wieder ein Tiefschlag für Guardiola – Manchester City verspielt 3:0 gegen Außenseiter
# Text: Tore von Gündogan und Haaland reichen Manchester City nicht zu einem dringend benötigten Erfolg. Die Mannschaft von Pep Guardiola bricht nach einem 3:0 noch auseinander. Ein besonderes Jubiläum feiert Barcelonas Robert Lewandowski.
# --------------------------------------------------
# Titel: Ehemaliger Bundesliga-Spieler Jan Furtok mit 62 Jahren gestorben
# Text: Der Pole Jan Furtok spielte in der Bundesliga für den Hamburger SV sowie Eintracht Frankfurt und wurde durch seine Tore populär. Vor drei Jahren wurde eine schwere Erkrankung bekannt, die dem Ex-Profi merklich zusetzte. Nun ist Furtok mit 62 gestorben.
# --------------------------------------------------
# Titel: „Es gibt keine Grüppchen mehr“, sagt Neuer vielsagend über den FC Bayern
# Text: Manuel Neuer spricht vor dem Champions-League-Spiel gegen Paris über die Veränderungen beim FC Bayern. Der Kapitän gewährt dabei Einblicke ins Innenleben des wiedererstarkten Rekordmeisters. Seine Sätze werfen kein gutes Licht auf Ex-Trainer Thomas Tuchel.
# --------------------------------------------------
# Titel: „15 Minuten später war alles online“ – Ex-Trainer rechnet mit Schalke ab
# Text: Knapp ein Jahr lang war Karel Geraerts Trainer von Schalke 04, ehe er im September entlassen wurde. Nun rechnet der Belgier ab und lässt dabei kaum einen Stein auf dem anderen. Einen Spieler knöpft sich Geraerts explizit vor.
# --------------------------------------------------
# Titel: Englischer Fußballverband führt Quoten für nicht-weiße Trainer ein
# Text: Männlich und weiß sind mit Abstand die meisten Trainer der englischen Fußball-Auswahlmannschaften. Das soll sich schnell ändern. Der englische Verband definiert dafür in einem Strategiepapier ambitionierte Ziele.
# --------------------------------------------------
# Titel: In den Wald oder in den Keller? Trainieren für den Krisenfall
# Text:
# --------------------------------------------------
# Titel: Leben entlang der Frontlinie - Alltag der Ukrainer zwischen Gleitbomben und Raketenfeuer
# Text:
# --------------------------------------------------
# Titel: Verbrechen. Versagen. Verfall. Deutschlands Brennpunkte
# Text:
# --------------------------------------------------
# Titel: „Kann mich nicht darüber beklagen, dass ich nicht genügend Solidarität habe“
# Text:
# --------------------------------------------------
# Titel: Ein Mann. Ein Motor. Eine Legende. - AMG
# Text:
# --------------------------------------------------
# Titel: Test Extrem – Die Spezialprüfer der Bundeswehr
# Text:
# --------------------------------------------------
# Titel: Die Bundespolizei – Im Einsatz für Deutschland
# Text:
# --------------------------------------------------
# Titel: Die Bundespolizei – Zu Wasser, zu Lande und in der Luft
# Text:
# --------------------------------------------------
# Titel: Die Bundespolizei – Eine starke Truppe
# Text:
# --------------------------------------------------
# Titel: Linienbus brennt aus - Stau auf Autobahn 81 und 8
# Text:
# --------------------------------------------------
# Titel: 69-Jährige wird angefahren und schwer verletzt
# Text:
# --------------------------------------------------
# Titel: Hamas beharrt auf Bedingungen für Gaza-Waffenruhe
# Text:
# --------------------------------------------------
# Titel: Wetter zeigt sich regnerisch und teils stürmisch
# Text:
# --------------------------------------------------
# Titel: Taylor Swift will bei Tour-Finale noch einmal alles geben
# Text:
# --------------------------------------------------
# Titel: Die Mammutpläne der Bahn – und die Realität
# Text:
# --------------------------------------------------
# Titel: Volkswagen in China verkauft umstrittenes Werk in Xinjiang
# Text:
# --------------------------------------------------
# Titel: Weidinger für besseren Schutz vor Haustürgeschäften
# Text:
# --------------------------------------------------
# Titel: Berlin sucht Tausende Wahlhelfer für den 23. Februar
# Text:
# --------------------------------------------------
# Titel: Wie das Immunsystem unsere Stimmung beeinflusst
# Text:
# --------------------------------------------------
# Titel: „Wir richten uns ein“ – 65 Prozent der Ukrainer wollen bleiben, sagt der Behördenchef
# Text:
# --------------------------------------------------
# Titel: Geldautomat im Kreis Kassel gesprengt
# Text:
# --------------------------------------------------
# Titel: Über Tulpen reden: Neues Buch von Suter und Stuckrad-Barre
# Text:
# --------------------------------------------------
# Titel: 31-Jähriger in Berlin getötet – Zeugen berichten von mehreren Schüssen und Blut auf der Straße
# Text:
# --------------------------------------------------
# Titel: Umfrage: Klare Mehrheit für rot-grün in Hamburg
# Text:
# --------------------------------------------------
# Titel: Laster prallt auf Autobahn 6 in Warnleit-Anhänger
# Text:
# --------------------------------------------------
# Titel: SPD und BSW einigen sich auf Koalitionsvertrag in Brandenburg
# Text:
# --------------------------------------------------
# Titel: Geldautomat in Bayreuth gesprengt - Täter flüchtig
# Text:
# --------------------------------------------------
# Titel: Koalitionsvertrag von SPD und BSW in Brandenburg steht
# Text:
# --------------------------------------------------
# Titel: SPD und BSW: Koalitionsvertrag in Brandenburg steht
# Text:
# --------------------------------------------------
# Titel: Mann in Berlin getötet - Zeugen berichten von Schüssen
# Text:
# --------------------------------------------------
# Titel: Buh-Rufe für ManCity - Guardiola: «Wir sind zerbrechlich»
# Text:
# --------------------------------------------------
# Titel: „Auf absolutem Tiefpunkt“ – Mit Pistorius stünde die SPD bei 21 Prozent, sagt der Forsa-Chef
# Text:
# --------------------------------------------------
# Titel: Theaterfestival «Impronale» in Halle gewollt reduziert
# Text:
# --------------------------------------------------
# Titel: Wo das Hochhaus noch eine Zukunft hat – und wo nicht
# Text:
# --------------------------------------------------
# Titel: Niedersachsens bemerkenswerte Wasser-Wende
# Text:
# --------------------------------------------------
# Titel: „Es ist ein lautes Lachen über ein müdes System“
# Text:
# --------------------------------------------------
# Titel: Ein stiller Pionier der Gemüseküche
# Text:
# --------------------------------------------------
# Titel: „Ich hatte in meiner Kindheit ein traumatisches Erlebnis. Muss mein Mann das wissen?“
# Text:
# --------------------------------------------------
# Titel: In Freiburgs Altstadt überstand nur das Münster die mehr als 1700 Tonnen Bomben
# Text:
# --------------------------------------------------
# Titel: Skifahren und Surfen – in Kalifornien geht beides
# Text:
# --------------------------------------------------
# Titel: „Bedarf auf Jahre gedeckt“, sagt Kubicki über Grüne – Thüringens CDU-Chef fürchtet Kemmerich-Moment
# Text:
# --------------------------------------------------
# Titel: Brand von Geräteschuppen - 500.000 Euro Schaden
# Text:
# --------------------------------------------------
# Titel: Ein Verletzter nach Auffahrunfall auf A4
# Text:
# --------------------------------------------------
# Titel: Kims Wandlung: Tor-Premiere macht Matchwinner «sehr stolz»
# Text:
# --------------------------------------------------
# Titel: Solarleistung pro Kopf: Lippstadt führt NRW-Rangliste an
# Text:
# --------------------------------------------------
# Titel: Krebsfrüherkennung nach Corona-Einbruch teils nachgeholt
# Text:
# --------------------------------------------------
# Titel: Eltern stellen Forderungen zur Schulpolitik auf
# Text:
# --------------------------------------------------
# Titel: Goldschmidt fordert «starkes Hochwasserschutzgesetz»
# Text:
# --------------------------------------------------
# Titel: Zwischen Rabatt und Risiko - Was am Black Friday wichtig ist
# Text:
# --------------------------------------------------
# Titel: Waffenruhe zwischen Israel und Hisbollah in Kraft – auch Hamas offenbar bereit für Feuerpause
# Text:
# --------------------------------------------------
# Titel: Eberl buhlt um Kimmich: «Abenteuer» oder «Bayern-Legende»?
# Text:
# --------------------------------------------------
# Titel: Neureuther adelt Shiffrin: «Wird nie wieder jemanden geben»
# Text:
# --------------------------------------------------
# Titel: Auslosung für Gladiatoren-Kämpfe im Kolosseum beginnt heute
# Text:
# --------------------------------------------------
# Titel: RB-Profis stärken Rose: «Keinen besseren Trainer vorstellen»
# Text:
# --------------------------------------------------
# Titel: Das bedeutet die Waffenruhe zwischen Israel und Hisbollah für den Nahost-Krieg
# Text:
# --------------------------------------------------
# Titel: „14 Jahre sind weg“ – Justizopfer verklagt Freistaat Bayern auf 750.000 Euro
# Text:
# --------------------------------------------------
# Titel: Die Folgen des Zoll-Zorns und die Aktie für die Babyboom-Kombi
# Text:
# --------------------------------------------------
# Titel: Erfolg aus Karlsruhe – Deutsches KI-Start-up Black Forest Lab soll eine Milliarde Dollar wert sein
# Text:
# --------------------------------------------------
# Titel: „Outsider“ – Ex-Kandidat Peer Steinbrück gibt seiner SPD und Scholz kaum noch Chancen
# Text:
# --------------------------------------------------
# Titel: Israelische Armee vermeldet Tötung eines hochrangigen Hamas-Scharfschützen
# Text:
# --------------------------------------------------
# Titel: Kanzlerkandidat Merz? „Ich gönne ihm das“, sagt die Pop-Literatin Angela Merkel
# Text:
# --------------------------------------------------
# Titel: „Nackte-Kanone“-Macher im Alter von 80 Jahren gestorben
# Text:
# --------------------------------------------------
# Titel: Nächster Doppelpack – Wirtz spielt überragend bei Leverkusens Kantersieg gegen Salzburg
# Text:
# --------------------------------------------------
# Titel: Wieder ein Tiefschlag für Guardiola – Manchester City verspielt 3:0 gegen Außenseiter
# Text:
# --------------------------------------------------
# Titel: „Können noch ein, zwei Tore mehr schießen“ – Bayern feiert dominanten Sieg gegen PSG
# Text:
# --------------------------------------------------
# Titel: Warum der „1701 Plus“-Deal ein Erfolg für Israels aggressive Strategie ist
# Text:
# --------------------------------------------------
# Titel: „Es gibt keine Grüppchen mehr“, sagt Neuer vielsagend über den FC Bayern
# Text:
# --------------------------------------------------
# Titel: „Wenn es hilft, dann soll man sagen: ‚Merkel war‘s‘“
# Text:
# --------------------------------------------------
# Titel: Die Frage, wie lang der Plan der kontrollierten Eskalation noch aufgeht
# Text:
# --------------------------------------------------
# Titel: Otto-Gutschein
# Text:
# --------------------------------------------------
# Titel: Amazon-Gutschein
# Text:
# --------------------------------------------------
# Titel: Zalando-Gutschein
# Text:
# --------------------------------------------------
# Titel: Saturn-Angebot
# Text:
# --------------------------------------------------
# Titel: H&M-Rabattcode
# Text:
# --------------------------------------------------
# Titel: Adidas-Gutscheine
# Text:
# --------------------------------------------------
# 160

# %% [markdown]
# ## Create DataFrame

# %%
parts_of_path = all_path[0].split(os.sep)
path = os.path.join(parts_of_path[-2], parts_of_path[-1])

print(f"Filename: {path}")
# Out:
# Filename: data-lake_2024_11/2024-11-23-faz.html

# %%
def get_news_data(file_path):
    """Extrahiert die relevanten Daten aus einer HTML-Datei basierend auf dem Dateinamen."""
    with open(file_path, "r", encoding="utf-8") as f:
        html = f.read()
    
    bs = BeautifulSoup(html, "html.parser")
    filename = os.path.basename(file_path)
    date = "-".join(filename.split("-")[:3])  # Datum aus Dateiname extrahieren
    parts_of_path = file_path.split(os.sep)
    path = os.path.join(parts_of_path[-2], parts_of_path[-1])
    
    data = []
    
    if "faz" in filename:
        teasers = bs.select(".top1-teaser__body-title, .teaser-object__title")
        for teaser in teasers:
            title = teaser.get_text(strip=True)
            text_element = teaser.find_next(class_="teaser-object__teaser-text")
            text = text_element.get_text(strip=True) if text_element else " "
            data.append({"Zeitung": "FAZ", "Pfad": path, "Datum": date, "Überschrift": title, "Text": text})
    
    elif "sz" in filename:
        articles = bs.find_all("article")
        for article in articles:
            title_element = article.select_one('[data-manual="teaser-title"]')
            title = title_element.get_text(strip=True) if title_element else " "
            text_element = article.select_one('[data-manual="teaser-text"]')
            text = text_element.get_text(strip=True) if text_element else " "
            data.append({"Zeitung": "SZ", "Pfad": path, "Datum": date, "Überschrift": title, "Text": text})
    
    elif "welt" in filename:
        articles = bs.find_all("article")
        for article in articles:
            title_element = article.select_one('.c-teaser__headline')
            title = title_element.get_text(strip=True) if title_element else " "
            text_element = article.select_one('.c-teaser__intro')
            text = text_element.get_text(strip=True) if text_element else " "
            data.append({"Zeitung": "Welt", "Pfad": path, "Datum": date, "Überschrift": title, "Text": text})
    
    return data

# %%
output_dir = Path.cwd().parent / "output"
all_data = []

for file_path in all_path:
    all_data.extend(get_news_data(file_path))

# DataFrame erstellen
df = pd.DataFrame(all_data)

# SQLite-Datenbank speichern
db_path = output_dir / "news_data.sqlite"
conn = sqlite3.connect(db_path)
df.to_sql("news", conn, if_exists="replace", index=False)
conn.close()

print(f"Datenbank gespeichert unter: {db_path}")
# Out:
# Datenbank gespeichert unter: /Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/output/news_data.sqlite

# %% [markdown]
# # Create Result

# %%
path_to_sqlite = Path.cwd().parent / "output" / "news_data.sqlite"
path_to_sqlite
# Out:
# PosixPath('/Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/output/news_data.sqlite')

# %%
connection = sqlite3.connect(path_to_sqlite)
query = "SELECT * FROM news"
df = pd.read_sql_query(query, connection)
df.head()
# Out:
#   Zeitung                                   Pfad       Datum  \
# 0     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 1     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 2     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 3     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 4     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
#
#                                          Überschrift  \
# 0          Der richtige Mann in der falschen Partei?
# 1                    Das Ende einer bizarren K-Frage
# 2      Was das Northvolt-Debakel für Europa bedeutet
# 3       Das zähe Klimaringen in Baku nimmt kein Ende
# 4  „Wir kommen nicht so schnell voran, wie es mög...
#
#                                                 Text
# 0  Boris Pistorius verzichtet auf die Kandidatur ...
# 1  Pistorius hätte die Debatte im Keim ersticken ...
# 2  Der schwedische Batterie-Pionier Northvolt käm...
# 3  Auch die Verlängerung ins Wochenende hinein ha...
# 4  Kommenden Montag findet in Berlin ein Long-Cov...

# %%
df.shape
# Out:
# (45143, 5)

# %% [markdown]
# ## Data cleaning

# %%
df[(df["Überschrift"] == " ") & (df["Text"] != " ")].shape
# Out:
# (0, 5)

# %%
df[(df["Überschrift"] == " ") & (df["Text"] == " ")].shape
# Out:
# (557, 5)

# %%
45143-557
# Out:
# 44586

# %%
df.drop(df[df["Überschrift"] == " "].index, inplace=True)
df.shape
# Out:
# (44586, 5)

# %% [markdown]
# ### Lowercasing

# %%
df["Überschrift"] = df["Überschrift"].str.lower()
df["Text"] = df["Text"].str.lower()
df.head()
# Out:
#   Zeitung                                   Pfad       Datum  \
# 0     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 1     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 2     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 3     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 4     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
#
#                                          Überschrift  \
# 0          der richtige mann in der falschen partei?
# 1                    das ende einer bizarren k-frage
# 2      was das northvolt-debakel für europa bedeutet
# 3       das zähe klimaringen in baku nimmt kein ende
# 4  „wir kommen nicht so schnell voran, wie es mög...
#
#                                                 Text
# 0  boris pistorius verzichtet auf die kandidatur ...
# 1  pistorius hätte die debatte im keim ersticken ...
# 2  der schwedische batterie-pionier northvolt käm...
# 3  auch die verlängerung ins wochenende hinein ha...
# 4  kommenden montag findet in berlin ein long-cov...

# %% [markdown]
# ### Sonderzeichen

# %%
df["Überschrift"] = df["Überschrift"].str.replace(r'[^a-zA-ZäöüÄÖÜß -]', '', regex=True)
df["Text"] = df["Text"].str.replace(r'[^a-zA-ZäöüÄÖÜß -]', '', regex=True)
df.head()
# Out:
#   Zeitung                                   Pfad       Datum  \
# 0     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 1     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 2     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 3     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 4     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
#
#                                          Überschrift  \
# 0           der richtige mann in der falschen partei
# 1                    das ende einer bizarren k-frage
# 2      was das northvolt-debakel für europa bedeutet
# 3       das zähe klimaringen in baku nimmt kein ende
# 4  wir kommen nicht so schnell voran wie es mögli...
#
#                                                 Text
# 0  boris pistorius verzichtet auf die kandidatur ...
# 1  pistorius hätte die debatte im keim ersticken ...
# 2  der schwedische batterie-pionier northvolt käm...
# 3  auch die verlängerung ins wochenende hinein ha...
# 4  kommenden montag findet in berlin ein long-cov...

# %% [markdown]
# ### Stopwords

# %%
stopwords_url = "https://raw.githubusercontent.com/solariz/german_stopwords/master/german_stopwords_full.txt"
stopwords = requests.get(stopwords_url, allow_redirects=True).text.split("\n")[9:] # hier cutten, weil davor keine Stopwords kommen
stopwords
# Out:
# ['ab',
#  'aber',
#  'abermaliges',
#  'abermals',
#  'abgerufen',
#  'abgerufene',
#  'abgerufener',
#  'abgerufenes',
#  'abgesehen',
#  'acht',
#  'aehnlich',
#  'aehnliche',
#  'aehnlichem',
#  'aehnlichen',
#  'aehnlicher',
#  'aehnliches',
#  'aehnlichste',
#  'aehnlichstem',
#  'aehnlichsten',
#  'aehnlichster',
#  'aehnlichstes',
#  'aeusserst',
#  'aeusserste',
#  'aeusserstem',
#  'aeussersten',
#  'aeusserster',
#  'aeusserstes',
#  'ähnlich',
#  'ähnliche',
#  'ähnlichem',
#  'ähnlichen',
#  'ähnlicher',
#  'ähnliches',
#  'ähnlichst',
#  'ähnlichste',
#  'ähnlichstem',
#  'ähnlichsten',
#  'ähnlichster',
#  'ähnlichstes',
#  'alle',
#  'allein',
#  'alleine',
#  'allem',
#  'allemal',
#  'allen',
#  'allenfalls',
#  'allenthalben',
#  'aller',
#  'allerdings',
#  'allerlei',
#  'alles',
#  'allesamt',
#  'allg',
#  'allg.',
#  'allgemein',
#  'allgemeine',
#  'allgemeinem',
#  'allgemeinen',
#  'allgemeiner',
#  'allgemeines',
#  'allgemeinste',
#  'allgemeinstem',
#  'allgemeinsten',
#  'allgemeinster',
#  'allgemeinstes',
#  'allmählich',
#  'allzeit',
#  'allzu',
#  'als',
#  'alsbald',
#  'also',
#  'am',
#  'an',
#  'and',
#  'andauernd',
#  'andauernde',
#  'andauerndem',
#  'andauernden',
#  'andauernder',
#  'andauerndes',
#  'ander',
#  'andere',
#  'anderem',
#  'anderen',
#  'anderenfalls',
#  'anderer',
#  'andererseits',
#  'anderes',
#  'anderm',
#  'andern',
#  'andernfalls',
#  'anderr',
#  'anders',
#  'anderst',
#  'anderweitig',
#  'anderweitige',
#  'anderweitigem',
#  'anderweitigen',
#  'anderweitiger',
#  'anderweitiges',
#  'anerkannt',
#  'anerkannte',
#  'anerkannter',
#  'anerkanntes',
#  'anfangen',
#  'anfing',
#  'angefangen',
#  'angesetze',
#  'angesetzt',
#  'angesetzten',
#  'angesetzter',
#  'ans',
#  'anscheinend',
#  'ansetzen',
#  'ansonst',
#  'ansonsten',
#  'anstatt',
#  'anstelle',
#  'arbeiten',
#  'auch',
#  'auf',
#  'aufgehört',
#  'aufgrund',
#  'aufhören',
#  'aufhörte',
#  'aufzusuchen',
#  'augenscheinlich',
#  'augenscheinliche',
#  'augenscheinlichem',
#  'augenscheinlichen',
#  'augenscheinlicher',
#  'augenscheinliches',
#  'augenscheinlichst',
#  'augenscheinlichste',
#  'augenscheinlichstem',
#  'augenscheinlichsten',
#  'augenscheinlichster',
#  'augenscheinlichstes',
#  'aus',
#  'ausdrücken',
#  'ausdrücklich',
#  'ausdrückliche',
#  'ausdrücklichem',
#  'ausdrücklichen',
#  'ausdrücklicher',
#  'ausdrückliches',
#  'ausdrückt',
#  'ausdrückte',
#  'ausgenommen',
#  'ausgenommene',
#  'ausgenommenem',
#  'ausgenommenen',
#  'ausgenommener',
#  'ausgenommenes',
#  'ausgerechnet',
#  'ausgerechnete',
#  'ausgerechnetem',
#  'ausgerechneten',
#  'ausgerechneter',
#  'ausgerechnetes',
#  'ausnahmslos',
#  'ausnahmslose',
#  'ausnahmslosem',
#  'ausnahmslosen',
#  'ausnahmsloser',
#  'ausnahmsloses',
#  'außen',
#  'ausser',
#  'ausserdem',
#  'außerhalb',
#  'äusserst',
#  'äusserste',
#  'äusserstem',
#  'äussersten',
#  'äusserster',
#  'äusserstes',
#  'author',
#  'autor',
#  'baelde',
#  'bald',
#  'bälde',
#  'bearbeite',
#  'bearbeiten',
#  'bearbeitete',
#  'bearbeiteten',
#  'bedarf',
#  'bedürfen',
#  'bedurfte',
#  'been',
#  'befahl',
#  'befiehlt',
#  'befiehlte',
#  'befohlene',
#  'befohlens',
#  'befragen',
#  'befragte',
#  'befragten',
#  'befragter',
#  'begann',
#  'beginnen',
#  'begonnen',
#  'behalten',
#  'behielt',
#  'bei',
#  'beide',
#  'beidem',
#  'beiden',
#  'beider',
#  'beiderlei',
#  'beides',
#  'beim',
#  'beinahe',
#  'beisammen',
#  'beispielsweise',
#  'beitragen',
#  'beitrugen',
#  'bekannt',
#  'bekannte',
#  'bekannter',
#  'bekanntlich',
#  'bekanntliche',
#  'bekanntlichem',
#  'bekanntlichen',
#  'bekanntlicher',
#  'bekanntliches',
#  'bekennen',
#  'benutzt',
#  'bereits',
#  'berichten',
#  'berichtet',
#  'berichtete',
#  'berichteten',
#  'besonders',
#  'besser',
#  'bessere',
#  'besserem',
#  'besseren',
#  'besserer',
#  'besseres',
#  'bestehen',
#  'besteht',
#  'bestenfalls',
#  'bestimmt',
#  'bestimmte',
#  'bestimmtem',
#  'bestimmten',
#  'bestimmter',
#  'bestimmtes',
#  'beträchtlich',
#  'beträchtliche',
#  'beträchtlichem',
#  'beträchtlichen',
#  'beträchtlicher',
#  'beträchtliches',
#  'betraechtlich',
#  'betraechtliche',
#  'betraechtlichem',
#  'betraechtlichen',
#  'betraechtlicher',
#  'betraechtliches',
#  'betreffend',
#  'betreffende',
#  'betreffendem',
#  'betreffenden',
#  'betreffender',
#  'betreffendes',
#  'bevor',
#  'bez',
#  'bez.',
#  'bezgl',
#  'bezgl.',
#  'bezueglich',
#  'bezüglich',
#  'bietet',
#  'bin',
#  'bis',
#  'bisher',
#  'bisherige',
#  'bisherigem',
#  'bisherigen',
#  'bisheriger',
#  'bisheriges',
#  'bislang',
#  'bisschen',
#  'bist',
#  'bitte',
#  'bleiben',
#  'bleibt',
#  'blieb',
#  'bloss',
#  'böden',
#  'boeden',
#  'brachte',
#  'brachten',
#  'brauchen',
#  'braucht',
#  'bräuchte',
#  'bringen',
#  'bsp',
#  'bsp.',
#  'bspw',
#  'bspw.',
#  'bzw',
#  'bzw.',
#  'ca',
#  'ca.',
#  'circa',
#  'da',
#  'dabei',
#  'dadurch',
#  'dafuer',
#  'dafür',
#  'dagegen',
#  'daher',
#  'dahin',
#  'dahingehend',
#  'dahingehende',
#  'dahingehendem',
#  'dahingehenden',
#  'dahingehender',
#  'dahingehendes',
#  'dahinter',
#  'damalige',
#  'damaligem',
#  'damaligen',
#  'damaliger',
#  'damaliges',
#  'damals',
#  'damit',
#  'danach',
#  'daneben',
#  'dank',
#  'danke',
#  'danken',
#  'dann',
#  'dannen',
#  'daran',
#  'darauf',
#  'daraus',
#  'darf',
#  'darfst',
#  'darin',
#  'darüber',
#  'darüberhinaus',
#  'darueber',
#  'darueberhinaus',
#  'darum',
#  'darunter',
#  'das',
#  'daß',
#  'dass',
#  'dasselbe',
#  'Dat',
#  'davon',
#  'davor',
#  'dazu',
#  'dazwischen',
#  'dein',
#  'deine',
#  'deinem',
#  'deinen',
#  'deiner',
#  'deines',
#  'dem',
#  'demgegenüber',
#  'demgegenueber',
#  'demgemaess',
#  'demgemäss',
#  'demnach',
#  'demselben',
#  'den',
#  'denen',
#  'denkbar',
#  'denkbare',
#  'denkbarem',
#  'denkbaren',
#  'denkbarer',
#  'denkbares',
#  'denn',
#  'dennoch',
#  'denselben',
#  'der',
#  'derart',
#  'derartig',
#  'derartige',
#  'derartigem',
#  'derartigen',
#  'derartiger',
#  'derem',
#  'deren',
#  'derer',
#  'derjenige',
#  'derjenigen',
#  'derselbe',
#  'derselben',
#  'derzeit',
#  'derzeitig',
#  'derzeitige',
#  'derzeitigem',
#  'derzeitigen',
#  'derzeitiges',
#  'des',
#  'deshalb',
#  'desselben',
#  'dessen',
#  'dessenungeachtet',
#  'desto',
#  'desungeachtet',
#  'deswegen',
#  'dich',
#  'die',
#  'diejenige',
#  'diejenigen',
#  'dies',
#  'diese',
#  'dieselbe',
#  'dieselben',
#  'diesem',
#  'diesen',
#  'dieser',
#  'dieses',
#  'diesseitig',
#  'diesseitige',
#  'diesseitigem',
#  'diesseitigen',
#  'diesseitiger',
#  'diesseitiges',
#  'diesseits',
#  'dinge',
#  'dir',
#  'direkt',
#  'direkte',
#  'direkten',
#  'direkter',
#  'doch',
#  'doppelt',
#  'dort',
#  'dorther',
#  'dorthin',
#  'dran',
#  'drauf',
#  'drei',
#  'dreißig',
#  'drin',
#  'dritte',
#  'drüber',
#  'drueber',
#  'drum',
#  'drunter',
#  'du',
#  'duerfte',
#  'duerften',
#  'duerftest',
#  'duerftet',
#  'dunklen',
#  'durch',
#  'durchaus',
#  'durchweg',
#  'durchwegs',
#  'dürfen',
#  'durfte',
#  'dürfte',
#  'durften',
#  'dürften',
#  'durftest',
#  'dürftest',
#  'durftet',
#  'dürftet',
#  'eben',
#  'ebenfalls',
#  'ebenso',
#  'ect',
#  'ect.',
#  'ehe',
#  'eher',
#  'eheste',
#  'ehestem',
#  'ehesten',
#  'ehester',
#  'ehestes',
#  'eigen',
#  'eigene',
#  'eigenem',
#  'eigenen',
#  'eigener',
#  'eigenes',
#  'eigenst',
#  'eigentlich',
#  'eigentliche',
#  'eigentlichem',
#  'eigentlichen',
#  'eigentlicher',
#  'eigentliches',
#  'ein',
#  'einbaün',
#  'eine',
#  'einem',
#  'einen',
#  'einer',
#  'einerlei',
#  'einerseits',
#  'eines',
#  'einfach',
#  'einführen',
#  'einführte',
#  'einführten',
#  'eingesetzt',
#  'einig',
#  'einige',
#  'einigem',
#  'einigen',
#  'einiger',
#  'einigermaßen',
#  'einiges',
#  'einmal',
#  'einmalig',
#  'einmalige',
#  'einmaligem',
#  'einmaligen',
#  'einmaliger',
#  'einmaliges',
#  'eins',
#  'einseitig',
#  'einseitige',
#  'einseitigen',
#  'einseitiger',
#  'einst',
#  'einstmals',
#  'einzig',
#  'empfunden',
#  'ende',
#  'entgegen',
#  'entlang',
#  'entsprechend',
#  'entsprechende',
#  'entsprechendem',
#  'entsprechenden',
#  'entsprechender',
#  'entsprechendes',
#  'entweder',
#  'er',
#  'ergänze',
#  'ergänzen',
#  'ergänzte',
#  'ergänzten',
#  'ergo',
#  'erhält',
#  'erhalten',
#  'erhielt',
#  'erhielten',
#  'erneut',
#  'eröffne',
#  'eröffnen',
#  'eröffnet',
#  'eröffnete',
#  'eröffnetes',
#  'erscheinen',
#  'erst',
#  'erste',
#  'erstem',
#  'ersten',
#  'erster',
#  'erstere',
#  'ersterem',
#  'ersteren',
#  'ersterer',
#  'ersteres',
#  'erstes',
#  'es',
#  'etc',
#  'etc.',
#  'etliche',
#  'etlichem',
#  'etlichen',
#  'etlicher',
#  'etliches',
#  'etwa',
#  'etwaige',
#  'etwas',
#  'euch',
#  'euer',
#  'eure',
#  'eurem',
#  'euren',
#  'eurer',
#  'eures',
#  'euretwegen',
#  'fall',
#  'falls',
#  'fand',
#  'fast',
#  'ferner',
#  'fertig',
#  'finde',
#  'finden',
#  'findest',
#  'findet',
#  'folgend',
#  'folgende',
#  'folgendem',
#  'folgenden',
#  'folgender',
#  'folgendermassen',
#  'folgendes',
#  'folglich',
#  'for',
#  'fordern',
#  'fordert',
#  'forderte',
#  'forderten',
#  'fort',
#  'fortsetzen',
#  'fortsetzt',
#  'fortsetzte',
#  'fortsetzten',
#  'fragte',
#  'frau',
#  'frei',
#  'freie',
#  'freier',
#  'freies',
#  'fuer',
#  'fuers',
#  'fünf',
#  'für',
#  'fürs',
#  'gab',
#  'gaenzlich',
#  'gaenzliche',
#  'gaenzlichem',
#  'gaenzlichen',
#  'gaenzlicher',
#  'gaenzliches',
#  'gängig',
#  'gängige',
#  'gängigen',
#  'gängiger',
#  'gängiges',
#  'ganz',
#  'ganze',
#  'ganzem',
#  'ganzen',
#  'ganzer',
#  'ganzes',
#  'gänzlich',
#  'gänzliche',
#  'gänzlichem',
#  'gänzlichen',
#  'gänzlicher',
#  'gänzliches',
#  'gar',
#  'gbr',
#  'geb',
#  'geben',
#  'geblieben',
#  'gebracht',
#  'gedurft',
#  'geehrt',
#  'geehrte',
#  'geehrten',
#  'geehrter',
#  'gefallen',
#  'gefälligst',
#  'gefällt',
#  'gefiel',
#  'gegeben',
#  'gegen',
#  'gegenüber',
#  'gegenueber',
#  'gehabt',
#  'gehalten',
#  'gehen',
#  'geht',
#  'gekommen',
#  'gekonnt',
#  'gemacht',
#  'gemaess',
#  'gemäss',
#  'gemeinhin',
#  'gemocht',
#  'genau',
#  'genommen',
#  'genug',
#  'gepriesener',
#  'gepriesenes',
#  'gerade',
#  'gern',
#  'gesagt',
#  'gesehen',
#  'gestern',
#  'gestrige',
#  'getan',
#  'geteilt',
#  'geteilte',
#  'getragen',
#  'getrennt',
#  'gewesen',
#  'gewiss',
#  'gewisse',
#  'gewissem',
#  'gewissen',
#  'gewisser',
#  'gewissermaßen',
#  'gewisses',
#  'gewollt',
#  'geworden',
#  'ggf',
#  'ggf.',
#  'gib',
#  'gibt',
#  'gilt',
#  'gleich',
#  'gleiche',
#  'gleichem',
#  'gleichen',
#  'gleicher',
#  'gleiches',
#  'gleichsam',
#  'gleichste',
#  'gleichstem',
#  'gleichsten',
#  'gleichster',
#  'gleichstes',
#  'gleichwohl',
#  'gleichzeitig',
#  'gleichzeitige',
#  'gleichzeitigem',
#  'gleichzeitigen',
#  'gleichzeitiger',
#  'gleichzeitiges',
#  'glücklicherweise',
#  'gluecklicherweise',
#  'gmbh',
#  'gottseidank',
#  'gratulieren',
#  'gratuliert',
#  'gratulierte',
#  'groesstenteils',
#  'grösstenteils',
#  'gruendlich',
#  'gründlich',
#  'gut',
#  'gute',
#  'guten',
#  'hab',
#  'habe',
#  'haben',
#  'habt',
#  'haette',
#  'haeufig',
#  'haeufige',
#  'haeufigem',
#  'haeufigen',
#  'haeufiger',
#  'haeufigere',
#  'haeufigeren',
#  'haeufigerer',
#  'haeufigeres',
#  'halb',
#  'hallo',
#  'halten',
#  'hast',
#  'hat',
#  'hätt',
#  'hatte',
#  'hätte',
#  'hatten',
#  'hätten',
#  'hattest',
#  'hattet',
#  'häufig',
#  'häufige',
#  'häufigem',
#  'häufigen',
#  'häufiger',
#  'häufigere',
#  'häufigeren',
#  'häufigerer',
#  'häufigeres',
#  'hen',
#  'her',
#  'heraus',
#  'herein',
#  'herum',
#  'heute',
#  'heutige',
#  'heutigem',
#  'heutigen',
#  'heutiger',
#  'heutiges',
#  'hier',
#  'hierbei',
#  'hiermit',
#  'hiesige',
#  'hiesigem',
#  'hiesigen',
#  'hiesiger',
#  'hiesiges',
#  'hin',
#  'hindurch',
#  'hinein',
#  'hingegen',
#  'hinlanglich',
#  'hinlänglich',
#  'hinten',
#  'hintendran',
#  'hinter',
#  'hinterher',
#  'hinterm',
#  'hintern',
#  'hinunter',
#  'hoch',
#  'höchst',
#  'höchstens',
#  'http',
#  'hundert',
#  'ich',
#  'igitt',
#  'ihm',
#  'ihn',
#  'ihnen',
#  'ihr',
#  'ihre',
#  'ihrem',
#  'ihren',
#  'ihrer',
#  'ihres',
#  'ihretwegen',
#  'ihrige',
#  'ihrigen',
#  'ihriges',
#  'im',
#  'immer',
#  'immerhin',
#  'immerwaehrend',
#  'immerwaehrende',
#  'immerwaehrendem',
#  'immerwaehrenden',
#  'immerwaehrender',
#  'immerwaehrendes',
#  'immerwährend',
#  'immerwährende',
#  'immerwährendem',
#  'immerwährenden',
#  'immerwährender',
#  'immerwährendes',
#  'immerzu',
#  'important',
#  'in',
#  'indem',
#  'indessen',
#  'Inf.',
#  'info',
#  'infolge',
#  'infolgedessen',
#  'information',
#  'innen',
#  'innerhalb',
#  'innerlich',
#  'ins',
#  'insbesondere',
#  'insgeheim',
#  'insgeheime',
#  'insgeheimer',
#  'insgesamt',
#  'insgesamte',
#  'insgesamter',
#  'insofern',
#  'inzwischen',
#  'irgend',
#  'irgendein',
#  'irgendeine',
#  'irgendeinem',
#  'irgendeiner',
#  'irgendeines',
#  'irgendetwas',
#  'irgendjemand',
#  'irgendjemandem',
#  'irgendwann',
#  'irgendwas',
#  'irgendwelche',
#  'irgendwen',
#  'irgendwenn',
#  'irgendwer',
#  'irgendwie',
#  'irgendwo',
#  'irgendwohin',
#  'ist',
#  'ja',
#  'jaehrig',
#  'jaehrige',
#  'jaehrigem',
#  'jaehrigen',
#  'jaehriger',
#  'jaehriges',
#  'jährig',
#  'jährige',
#  'jährigem',
#  'jährigen',
#  'jähriges',
#  'je',
#  'jede',
#  'jedem',
#  'jeden',
#  'jedenfalls',
#  'jeder',
#  'jederlei',
#  'jedes',
#  'jedesmal',
#  'jedoch',
#  'jeglichem',
#  'jeglichen',
#  'jeglicher',
#  'jegliches',
#  'jemals',
#  'jemand',
#  'jemandem',
#  'jemanden',
#  'jemandes',
#  'jene',
#  'jenem',
#  'jenen',
#  'jener',
#  'jenes',
#  'jenseitig',
#  'jenseitigem',
#  'jenseitiger',
#  'jenseits',
#  'jetzt',
#  'jung',
#  'junge',
#  'jungem',
#  'jungen',
#  'junger',
#  'junges',
#  'kaeumlich',
#  'kam',
#  'kann',
#  'kannst',
#  'kaum',
#  'käumlich',
#  'kein',
#  'keine',
#  'keinem',
#  'keinen',
#  'keiner',
#  'keinerlei',
#  'keines',
#  'keineswegs',
#  'klar',
#  'klare',
#  'klaren',
#  'klares',
#  'klein',
#  'kleinen',
#  'kleiner',
#  'kleines',
#  'koennen',
#  'koennt',
#  'koennte',
#  'koennten',
#  'koenntest',
#  'koenntet',
#  'komme',
#  'kommen',
#  'kommt',
#  'konkret',
#  'konkrete',
#  'konkreten',
#  'konkreter',
#  'konkretes',
#  'könn',
#  'können',
#  'könnt',
#  'konnte',
#  'könnte',
#  'konnten',
#  'könnten',
#  'konntest',
#  'könntest',
#  'konntet',
#  'könntet',
#  'kuenftig',
#  'kuerzlich',
#  'kuerzlichst',
#  'künftig',
#  'kürzlich',
#  'kürzlichst',
#  'laengst',
#  'lag',
#  'lagen',
#  'langsam',
#  'längst',
#  'längstens',
#  'lassen',
#  'laut',
#  'lediglich',
#  'leer',
#  'legen',
#  'legte',
#  ...]

# %%
def remove_stopwords(text, stopwords):
    # Den Text in Kleinbuchstaben umwandeln und dann in Wörter zerlegen
    words = text.lower().split()
    # Stopwords entfernen
    words = [word for word in words if word not in stopwords]
    # Die restlichen Wörter wieder zu einem Text zusammensetzen
    return " ".join(words)

# %%
df["Überschrift"] = df["Überschrift"].apply(lambda x: remove_stopwords(x, stopwords))
df["Text"] = df["Text"].apply(lambda x: remove_stopwords(x, stopwords))
df.head()
# Out:
#   Zeitung                                   Pfad       Datum  \
# 0     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 1     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 2     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 3     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 4     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
#
#                          Überschrift  \
# 0           richtige falschen partei
# 1                   bizarren k-frage
# 2  northvolt-debakel europa bedeutet
# 3              zähe klimaringen baku
# 4
#
#                                                 Text
# 0  boris pistorius verzichtet kandidatur unterstü...
# 1  pistorius debatte keim ersticken ließ laufen r...
# 2  schwedische batterie-pionier northvolt kämpft ...
# 3  verlängerung wochenende durchbruch weltklimako...
# 4  kommenden montag berlin long-covid-kongress ch...

# %% [markdown]
# ## Create "text_combined"

# %%
df["text_combined"] = df["Überschrift"] + " " + df["Text"]
df.head()
# Out:
#   Zeitung                                   Pfad       Datum  \
# 0     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 1     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 2     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 3     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
# 4     FAZ  data-lake_2024_11/2024-11-23-faz.html  2024-11-23
#
#                          Überschrift  \
# 0           richtige falschen partei
# 1                   bizarren k-frage
# 2  northvolt-debakel europa bedeutet
# 3              zähe klimaringen baku
# 4
#
#                                                 Text  \
# 0  boris pistorius verzichtet kandidatur unterstü...
# 1  pistorius debatte keim ersticken ließ laufen r...
# 2  schwedische batterie-pionier northvolt kämpft ...
# 3  verlängerung wochenende durchbruch weltklimako...
# 4  kommenden montag berlin long-covid-kongress ch...
#
#                                        text_combined
# 0  richtige falschen partei boris pistorius verzi...
# 1  bizarren k-frage pistorius debatte keim erstic...
# 2  northvolt-debakel europa bedeutet schwedische ...
# 3  zähe klimaringen baku verlängerung wochenende ...
# 4   kommenden montag berlin long-covid-kongress c...

# %% [markdown]
# ## Peform LDA

# %%
def perform_lda(df, n_topics=10):
    results = {}
    
    # Für jede Zeitung LDA ausführen
    for newspaper in df['Zeitung'].unique():
        # Filtere DataFrame nach Zeitung
        newspaper_df = df[df['Zeitung'] == newspaper]
        
        # CountVectorizer erstellen
        vectorizer = CountVectorizer(stop_words=stopwords)
        X = vectorizer.fit_transform(newspaper_df['text_combined'])
        
        # LDA Modell
        lda = LatentDirichletAllocation(n_components=n_topics, random_state=42)
        lda.fit(X)
        
        # Extrahiere die Top Wörter für jedes Thema
        feature_names = np.array(vectorizer.get_feature_names_out())
        topics = []
        
        for topic_idx, topic in enumerate(lda.components_):
            top_words_idx = topic.argsort()[:-11:-1]
            top_words = feature_names[top_words_idx]
            topics.append(" ".join(top_words))
        
        topic_distribution = lda.transform(X)
        # Durchschnitt über alle Dokumente
        avg_topic_distribution = topic_distribution.mean(axis=0)
        
        # Sortiere Topics nach Wahrscheinlichkeit & Indizes nach Wahrscheinlichkeit sortieren (absteigend)
        sorted_indices = np.argsort(avg_topic_distribution)[::-1]  # 
        
        sorted_topics = [topics[i] for i in sorted_indices]  # Sortierte Topics
        sorted_percentages = avg_topic_distribution[sorted_indices]  # Sortierte Wahrscheinlichkeiten
        sorted_percentages = (sorted_percentages / sorted_percentages.sum()) * 100  # In Prozent umrechnen
        
        # Ergebnisse speichern
        results[newspaper] = {"topics": sorted_topics, "percentages": sorted_percentages}
    
    return results

# %%
# LDA für das gesamte DataFrame durchführen
topics_by_newspaper = perform_lda(df)

# Ausgabe der Ergebnisse mit Prozenten
for newspaper, data in topics_by_newspaper.items():
    print(f"Top 10 Topics für {newspaper}:")
    for i, (topic, percentage) in enumerate(zip(data["topics"], data["percentages"]), 1):
        print(f"  Topic {i}: {topic} ({percentage:.2f}%)")
    print("\n")
# Out:
# /Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/.venv/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['dat', 'inf', 'zb'] not in stop_words.
#   warnings.warn(
# Top 10 Topics für FAZ:
#   Topic 1: scholz merz assads spd afd beste syrien trump land grünen (11.26%)
#   Topic 2: jahr welt deutschland blick faz besten deutschen daten frankfurt zeigen (10.72%)
#   Topic 3: jahr reise jobs besten jahren vielfalt beste welt überblick bringt (10.53%)
#   Topic 4: trump us trumps präsident donald usa liveblog geld deutschland präsidenten (10.36%)
#   Topic 5: ki trump deutschland reise euro millionen deutsche lernen welt new (9.83%)
#   Topic 6: deutschland deutsche stellt rolle spielt us grönland lässt bordeaux fokus (9.64%)
#   Topic 7: menschen große beste reise kalifornien besten deutschland inklusive booklet jahre (9.63%)
#   Topic 8: trump ki donald musk weihnachten elon faz beste deutschland bücher (9.62%)
#   Topic 9: frankfurt hessen beste eintracht jobs eltern berlin leben lässt menschen (9.39%)
#   Topic 10: deutschland deutschen faz menschen ukraine deutsche amazon etf funktioniert cdu (9.01%)
#
#
# Top 10 Topics für SZ:
#   Topic 1: wissen füllt felder is my trump rätsel sz magazin ratgeber (11.55%)
#   Topic 2: tipps bauen quer zahlenstraßen kreuz zug großmeister lässt kunst beste (10.90%)
#   Topic 3: bilder welt dämon große zukunft jahre schönes angst ecken schaffen (10.62%)
#   Topic 4: wörter bilden geschichte intelligenz trump erfahren emotionale amerika testen größten (10.41%)
#   Topic 5: passt bilder füllen quadrat gemeinsamkeit verlieren gesund welt gewicht späte (10.37%)
#   Topic 6: trump bayern deutsche musk fc us grippe usa entkommen intelligenzquotient (9.83%)
#   Topic 7: bekommen wege gehalt feldern logikrätsel melancholie leiser sorryyy joni behindertenwerkstätten (9.66%)
#   Topic 8: kinder klassiker leben china verändern legespiel computerspiel eltern mafiaprinzessin jahr (9.34%)
#   Topic 9: deutscher staatsbürger leben menschen afd gleichberechtigung toilette schüsse amoklauf deutschen (9.11%)
#   Topic 10: menschen suche trumps gelingt deutschland trump donald liebe kiste geheimen (8.20%)
#
#
# Top 10 Topics für Welt:
#   Topic 1: trump us donald ukraine trumps gutschein amazon präsident zalando aktien (12.61%)
#   Topic 2: merz spd cdu scholz angebot welt deutschland bayern saturn assad (11.42%)
#   Topic 3: welt deutschen ki deutschland bahn verrät otto gutschein deutsche erwartet (11.26%)
#   Topic 4: habeck deutschland grünen jahrhundert welt lude union robert menschen erklärt (10.63%)
#   Topic 5: deutschlands versagen verbrechen welt brennpunkte afd verfall deutschen duell tv (9.43%)
#   Topic 6: verletzt welt verletzte auto menschen schwer erklärt leipzig scholz fdp (9.40%)
#   Topic 7: adidas gutscheine welt deutschland usa jahren deutschen hamas menschen erklärt (9.19%)
#   Topic 8: deutschland leben musk legende alltag ukrainer motor aktien amg elon (8.87%)
#   Topic 9: ki hm rabattcode welt handel magdeburg menschen anschlag deutsche verändert (8.65%)
#   Topic 10: trump welt afd deutschland deutschen präsident polizei elon musk nrw (8.56%)

# %% [markdown]
# ## Plot Top Topics

# %%
def plot_top_topics(topics_by_newspaper, output_path):
    # Liste zur Speicherung der Daten für den Plot
    plot_data = []

    # Daten für jede Zeitung sammeln
    for newspaper, data in topics_by_newspaper.items():
        for i in range(3):  # Nur die Top 3 Topics nehmen
            plot_data.append({
                "Zeitung": newspaper,
                "Topic": f"{newspaper} - Topic {i+1}: {data['topics'][i]}",  # Zeitung + Topic Nummer
                "Wahrscheinlichkeit (%)": data["percentages"][i]
            })
    
    # DataFrame für die Visualisierung erstellen
    df_plot = pd.DataFrame(plot_data)

    # Stil setzen
    sns.set_theme(style="whitegrid")
    
    # Balkendiagramm mit Seaborn
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(
        data=df_plot, 
        x="Zeitung", 
        y="Wahrscheinlichkeit (%)", 
        hue="Topic",  # Hue enthält nun Zeitung + Topic
        palette="viridis"
    )
    
    # Titel & Labels
    plt.title("Top 3 Topics pro Zeitung", fontsize=14)
    plt.xlabel("Zeitung", fontsize=12)
    plt.ylabel("Wahrscheinlichkeit (%)", fontsize=12)
    plt.legend(title="Zeitung - Topic", bbox_to_anchor=(1, 1), loc='upper left')  # Legende mit Zeitung + Topic
    
    # Speichern als PDF
    plt.savefig(output_path, bbox_inches="tight")
    plt.close()  # Figure schließen, um Speicher freizugeben

# %%
output_path = Path.cwd().parent / "output"
plot_top_topics(topics_by_newspaper, output_path)

# %% [markdown]
# ## Save Text Results

# %%
def save_text_results(topics_by_newspaper, output_path):
    with open(output_path, "w", encoding="utf-8") as file:
        for newspaper, data in topics_by_newspaper.items():
            file.write(f"Top 10 Topics für {newspaper}:\n")
            for i, (topic, percentage) in enumerate(zip(data["topics"], data["percentages"]), 1):
                file.write(f"  Topic {i}: {topic} ({percentage:.2f}%)\n")
            file.write("\n")  # Leerzeile für bessere Lesbarkeit

# %% [markdown]
# ## Save all Results

# %%
pdf_path = os.path.join(Path.cwd().parent / "output", "result.pdf")
txt_path = os.path.join(Path.cwd().parent / "output", "full_result.txt")

# %%
plot_top_topics(topics_by_newspaper, pdf_path)
save_text_results(topics_by_newspaper, txt_path)

print(f"Grafik gespeichert unter: {pdf_path}")
print(f"Textdatei gespeichert unter: {txt_path}")
# Out:
# Grafik gespeichert unter: /Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/output/result.pdf
# Textdatei gespeichert unter: /Users/antonioaleksic/Documents/ADSC1_Prüfungsleistung/ADSC1/output/full_result.txt
